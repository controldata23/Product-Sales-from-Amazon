# %% [markdown]
# # Amazon Products Sales
#
# #### Exploratory Data Analysis by Chinedu David Nwolisa, August 2023
#
# #### https://www.linkedin.com/in/chinedu-nwolisa/
#
# Dataset provided by Rajeev Mishra (Owner)
#
# File: AmazonProducts.csv (188.6 MB)
#
# Dataset source: https://www.kaggle.com/datasets/rajeevmishragwl/amazon-product-sales
#
# Retrieved: 6-August-2023

# %% [markdown]
# ## The aim of this Analytics case study is to answer these two cardinal questions:
#
# * ### What are the trends in product sales?
#
# * ### What are the factors that influence product sales?

# %% [markdown]
# ## Outline of the Analysis process:
#
# * Phase 1: Importing the required Python packages
# * Phase 2: Acquiring the dataset
# * Phase 3: Data exploration
# * Phase 4: Data cleaning
# * Phase 5: Data mining
# * Phase 6: Data visualization
# * Phase 7: Reporting

# %% [markdown]
# ## Phase 1: Importing the required Python packages

# %%
# Let's import the required packages real quick!
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings as wn

# %% [markdown]
# ## Phase 2: Acquiring the dataset for Analysis (run this cell only once!)

# %%
# Let's read the dataset file into our environment and format it as a dataframe
os.chdir('Downloads')
wn.filterwarnings('ignore')
df = pd.read_csv('AmazonProducts.csv')
df
# Out:
#         Unnamed: 0                                               name  \
# 0                0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1                1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2                2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3                3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4                4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
# ...            ...                                                ...
# 551580        1099                Adidas Regular Fit Men's Track Tops
# 551581        1100          Redwolf Noice Toit Smort - Hoodie (Black)
# 551582        1101     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)
# 551583        1102                                    Puma Men Shorts
# 551584        1103  Mothercare Printed Cotton Elastane Girls Infan...
#
#            main_category      sub_category  \
# 0             appliances  Air Conditioners
# 1             appliances  Air Conditioners
# 2             appliances  Air Conditioners
# 3             appliances  Air Conditioners
# 4             appliances  Air Conditioners
# ...                  ...               ...
# 551580  sports & fitness              Yoga
# 551581  sports & fitness              Yoga
# 551582  sports & fitness              Yoga
# 551583  sports & fitness              Yoga
# 551584  sports & fitness              Yoga
#
#                                                     image  \
# 0       https://m.media-amazon.com/images/I/31UISB90sY...
# 1       https://m.media-amazon.com/images/I/51JFb7FctD...
# 2       https://m.media-amazon.com/images/I/51JFb7FctD...
# 3       https://m.media-amazon.com/images/I/51JFb7FctD...
# 4       https://m.media-amazon.com/images/I/41lrtqXPiW...
# ...                                                   ...
# 551580  https://m.media-amazon.com/images/I/71tHAR9pIY...
# 551581  https://m.media-amazon.com/images/I/41pKrMZ5lQ...
# 551582  https://m.media-amazon.com/images/I/41n9u+zNSc...
# 551583  https://m.media-amazon.com/images/I/51LoWv5JDt...
# 551584  https://m.media-amazon.com/images/I/814X-sI3DB...
#
#                                                      link ratings  \
# 0       https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2
# 1       https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2
# 2       https://www.amazon.in/LG-Inverter-Convertible-...     4.2
# 3       https://www.amazon.in/LG-Convertible-Anti-Viru...     4.0
# 4       https://www.amazon.in/Carrier-Inverter-Split-C...     4.1
# ...                                                   ...     ...
# 551580  https://www.amazon.in/Adidas-Regular-Mens-Trac...     3.2
# 551581  https://www.amazon.in/Redwolf-Noice-Smort-Cott...     2.0
# 551582  https://www.amazon.in/Redwolf-Schrute-Farms-Ho...     4.0
# 551583  https://www.amazon.in/Puma-Woven-Short-5208526...     4.4
# 551584  https://www.amazon.in/Mothercare-Carrot-Regula...     4.6
#
#        no_of_ratings discount_price actual_price
# 0              2,255        ₹32,999      ₹58,990
# 1              2,948        ₹46,490      ₹75,990
# 2              1,206        ₹34,490      ₹61,990
# 3                 69        ₹37,990      ₹68,990
# 4                630        ₹34,490      ₹67,790
# ...              ...            ...          ...
# 551580             9         ₹3,449       ₹4,599
# 551581             2         ₹1,199       ₹1,999
# 551582             1         ₹1,199       ₹1,999
# 551583            37            NaN          NaN
# 551584             5         ₹1,039       ₹1,299
#
# [551585 rows x 10 columns]

# %% [markdown]
# ## Phase 3: Exploring the dataset

# %%
# Let's see the first few records in the dataset
df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1           1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2           2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3           3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4           4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2         2,255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2         2,948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...     4.2         1,206
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.0            69
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...     4.1           630
#
#   discount_price actual_price
# 0        ₹32,999      ₹58,990
# 1        ₹46,490      ₹75,990
# 2        ₹34,490      ₹61,990
# 3        ₹37,990      ₹68,990
# 4        ₹34,490      ₹67,790

# %%
# Let's view the list of the fields in the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'main_category', 'sub_category', 'image', 'link',
#        'ratings', 'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='object')

# %%
# To see the number of rows and columns
df.shape
# Out:
# (551585, 10)

# %%
# To see the columns information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551585 entries, 0 to 551584
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      551585 non-null  int64
#  1   name            551585 non-null  object
#  2   main_category   551585 non-null  object
#  3   sub_category    551585 non-null  object
#  4   image           551585 non-null  object
#  5   link            551585 non-null  object
#  6   ratings         375791 non-null  object
#  7   no_of_ratings   375791 non-null  object
#  8   discount_price  490422 non-null  object
#  9   actual_price    533772 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 42.1+ MB

# %%
# To see the datatypes of each of the columns in the dataframe
df.dtypes
# Out:
# Unnamed: 0         int64
# name              object
# main_category     object
# sub_category      object
# image             object
# link              object
# ratings           object
# no_of_ratings     object
# discount_price    object
# actual_price      object
# dtype: object

# %%
# To display all statistics for each columns in the dataset
df.describe(include='all')
# Out:
#            Unnamed: 0                   name main_category sub_category  \
# count   551585.000000                 551585        551585       551585
# unique            NaN                 396210            20          112
# top               NaN  Zeya Yellow Gold Ring   accessories       Shirts
# freq              NaN                    718        116141        19200
# mean      7006.200471                    NaN           NaN          NaN
# std       5740.835523                    NaN           NaN          NaN
# min          0.000000                    NaN           NaN          NaN
# 25%       1550.000000                    NaN           NaN          NaN
# 50%       5933.000000                    NaN           NaN          NaN
# 75%      11482.000000                    NaN           NaN          NaN
# max      19199.000000                    NaN           NaN          NaN
#
#                                                     image  \
# count                                              551585
# unique                                             462414
# top     https://m.media-amazon.com/images/I/51uEPldT42...
# freq                                                 3044
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      link ratings  \
# count                                              551585  375791
# unique                                             551585      49
# top     https://www.amazon.in/Lloyd-Inverter-Convertib...     4.0
# freq                                                    1   36609
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#        no_of_ratings discount_price actual_price
# count         375791         490422       533772
# unique          8342          27511        23170
# top                1           ₹499         ₹999
# freq           39816          18248        48774
# mean             NaN            NaN          NaN
# std              NaN            NaN          NaN
# min              NaN            NaN          NaN
# 25%              NaN            NaN          NaN
# 50%              NaN            NaN          NaN
# 75%              NaN            NaN          NaN
# max              NaN            NaN          NaN

# %%
# To check for total number of missing values in each column of the whole dataframe
df.isnull().sum()
# Out:
# Unnamed: 0             0
# name                   0
# main_category          0
# sub_category           0
# image                  0
# link                   0
# ratings           175794
# no_of_ratings     175794
# discount_price     61163
# actual_price       17813
# dtype: int64

# %% [markdown]
# ## Phase 4: Data cleaning (wrangling)

# %%
# The fields 'Unnamed: 0', 'image', and 'link' are irrelevant to our analysis
# Let's remove these fields
df_dropped = df.drop(['Unnamed: 0', 'image', 'link'], axis = 1)
df_dropped
# Out:
#                                                      name     main_category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551583                                    Puma Men Shorts  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             sub_category ratings no_of_ratings discount_price actual_price
# 0       Air Conditioners     4.2         2,255        ₹32,999      ₹58,990
# 1       Air Conditioners     4.2         2,948        ₹46,490      ₹75,990
# 2       Air Conditioners     4.2         1,206        ₹34,490      ₹61,990
# 3       Air Conditioners     4.0            69        ₹37,990      ₹68,990
# 4       Air Conditioners     4.1           630        ₹34,490      ₹67,790
# ...                  ...     ...           ...            ...          ...
# 551580              Yoga     3.2             9         ₹3,449       ₹4,599
# 551581              Yoga     2.0             2         ₹1,199       ₹1,999
# 551582              Yoga     4.0             1         ₹1,199       ₹1,999
# 551583              Yoga     4.4            37            NaN          NaN
# 551584              Yoga     4.6             5         ₹1,039       ₹1,299
#
# [551585 rows x 7 columns]

# %%
# let's rename the columns to make them look proper.
df_dropped.columns = ['Name', 'Main Category', 'Sub-category', 'Ratings', 'No. Of Ratings', 'Discount Price', 'Actual Price']
df_dropped
# Out:
#                                                      Name     Main Category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551583                                    Puma Men Shorts  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             Sub-category Ratings No. Of Ratings Discount Price Actual Price
# 0       Air Conditioners     4.2          2,255        ₹32,999      ₹58,990
# 1       Air Conditioners     4.2          2,948        ₹46,490      ₹75,990
# 2       Air Conditioners     4.2          1,206        ₹34,490      ₹61,990
# 3       Air Conditioners     4.0             69        ₹37,990      ₹68,990
# 4       Air Conditioners     4.1            630        ₹34,490      ₹67,790
# ...                  ...     ...            ...            ...          ...
# 551580              Yoga     3.2              9         ₹3,449       ₹4,599
# 551581              Yoga     2.0              2         ₹1,199       ₹1,999
# 551582              Yoga     4.0              1         ₹1,199       ₹1,999
# 551583              Yoga     4.4             37            NaN          NaN
# 551584              Yoga     4.6              5         ₹1,039       ₹1,299
#
# [551585 rows x 7 columns]

# %%
# Let's check for total number of missing values in each fields of the whole dataframe
df_dropped.isnull().sum()
# Out:
# Name                   0
# Main Category          0
# Sub-category           0
# Ratings           175794
# No. Of Ratings    175794
# Discount Price     61163
# Actual Price       17813
# dtype: int64

# %%
# Let's calculate the percentage of the total dataset that has missing values
print((df_dropped.isnull().sum().sum() / np.product(df_dropped.shape)) * 100)
# Out:
# 11.151344372516087

# %%
# Since the missing/NaN values amount to less than 25% (one-quarter) of the total dataset, we can safely remove these rows
# To drop all rows with NaN values or missing values
df_dropped_2 = df_dropped.dropna(axis=0)
df_dropped_2
# Out:
#                                                      Name     Main Category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551579  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             Sub-category Ratings No. Of Ratings Discount Price Actual Price
# 0       Air Conditioners     4.2          2,255        ₹32,999      ₹58,990
# 1       Air Conditioners     4.2          2,948        ₹46,490      ₹75,990
# 2       Air Conditioners     4.2          1,206        ₹34,490      ₹61,990
# 3       Air Conditioners     4.0             69        ₹37,990      ₹68,990
# 4       Air Conditioners     4.1            630        ₹34,490      ₹67,790
# ...                  ...     ...            ...            ...          ...
# 551579              Yoga     4.6              6           ₹711         ₹999
# 551580              Yoga     3.2              9         ₹3,449       ₹4,599
# 551581              Yoga     2.0              2         ₹1,199       ₹1,999
# 551582              Yoga     4.0              1         ₹1,199       ₹1,999
# 551584              Yoga     4.6              5         ₹1,039       ₹1,299
#
# [340680 rows x 7 columns]

# %%
# Let's check for total number of missing values in each fields of the whole dataframe
df_dropped_2.isnull().sum()
# Out:
# Name              0
# Main Category     0
# Sub-category      0
# Ratings           0
# No. Of Ratings    0
# Discount Price    0
# Actual Price      0
# dtype: int64

# %%
# Out of 551585 total rows, we have 340680 left after we removed missing/NaN values
# Let's see the datatypes of each of the fields in the dataframe
df_dropped_2.dtypes
# Out:
# Name              object
# Main Category     object
# Sub-category      object
# Ratings           object
# No. Of Ratings    object
# Discount Price    object
# Actual Price      object
# dtype: object

# %%
# We can see that even the Ratings, No. Of Ratings, Discount Price, and Actual Price fields are Object columns
# Let's change the datatypes to Decimal, Integer, Decimal, and Decimal respectively

# %%
# to check for total number of missing values for ratings
df_dropped_2.Ratings.isnull().sum()
# Out:
# 0

# %%
# To check for unique values of ratings we used the unique method(unique()).
df_dropped_2.Ratings.unique()
# Out:
# array(['4.2', '4.0', '4.1', '4.3', '3.9', '3.8', '3.5', '4.6', '3.3',
#        '3.4', '3.7', '2.9', '5.0', '4.4', '3.6', '2.7', '4.5', '3.0',
#        '3.1', '4.8', '4.7', '3.2', '2.5', '1.0', '2.6', '2.8', '1.7',
#        'Get', '1.8', '2.4', '4.9', '2.2', '1.6', '1.9', '2.3', '2.0',
#        '1.4', '2.1', 'FREE', '1.2', '1.3', '1.5', '₹65', '1.1', '₹70',
#        '₹100', '₹99', '₹2.99'], dtype=object)

# %%
# We cannot convert Ratings field from Object to float due to presence of non-numeric data
# We have to get rid of these non-numeric values, by using .str.contains method to filter them out then drop them

# %%
# Lets match the rupee sign so that we can filter out irreleenat entries in our dataset.
df_dropped_2[df_dropped_2['Ratings'].str.contains('₹')]
# Out:
#                                                      Name     Main Category  \
# 224204  Lengthy Handle Shoulder Bag - Hand Made Wire K...       accessories
# 277756  ELECTROPRIME 2pcs Sheer Pink Black Lace Underw...    men's clothing
# 284642  ELECTROPRIME Men's Leather Briefs (Pack of 1) ...    men's clothing
# 286032  ELECTROPRIME Men's Underwear Artificial Leathe...    men's clothing
# 286033  ELECTROPRIME Lovely Men Sexy White See Through...    men's clothing
# 299759  ELECTROPRIME Men Zipper Fly Five Pockets Pleat...    men's clothing
# 368276  ELECTROPRIME 1F06 Breast Soap 100g Beauty Brea...  women's clothing
# 401191  Trendy Retail Military Tactical Vest Molle Air...    bags & luggage
# 401192  Trendy Retail Outdoor Hiking Sport Camping Din...    bags & luggage
# 401193  Trendy Retail 25KN Locking Carabiner Clip D-Ri...    bags & luggage
# 401194  Trendy Retail Ball Bearing Fishing Swivel with...    bags & luggage
# 401195  Trendy Retail Electronic Whistle Sports Electr...    bags & luggage
# 401196  Trendy Retail Outdoor Survival American Milita...    bags & luggage
# 401198  Trendy Retail Referee Metal Whistle Extra Loud...    bags & luggage
# 478074  Macaso Adjustable Eyewear Retainer, Universal ...       accessories
# 478075  Macaso Heart Shaped Sunglasses Women Party Eye...       accessories
# 506485  Trendy Retail Travel Duffel Bag Luggage Storag...    bags & luggage
# 506486  Trendy Retail Golf Bag for Storage Clothing Sh...    bags & luggage
# 506487  Trendy Retail Shooting Range Duffle Bags Milit...    bags & luggage
# 506488  Trendy Retail Heavy Duty Mesh Dive Bag Duffel ...    bags & luggage
# 506489  Trendy Retail Shooting Range Duffle Bags Milit...    bags & luggage
# 506490  Trendy Retail Golf Bag for Storage Clothing Sh...    bags & luggage
# 506492  Trendy Retail Heavy Duty Mesh Dive Bag Duffel ...    bags & luggage
#
#                 Sub-category Ratings                        No. Of Ratings  \
# 224204   Handbags & Clutches     ₹65    Usually dispatched in 6 to 7 days.
# 277756             Innerwear     ₹70   Usually dispatched in 4 to 5 weeks.
# 284642             Innerwear     ₹70   Usually dispatched in 4 to 5 weeks.
# 286032             Innerwear     ₹70   Usually dispatched in 4 to 5 weeks.
# 286033             Innerwear     ₹70   Usually dispatched in 4 to 5 weeks.
# 299759                 Jeans    ₹100   Usually dispatched in 4 to 5 weeks.
# 368276  Lingerie & Nightwear     ₹70   Usually dispatched in 4 to 5 weeks.
# 401191             Rucksacks     ₹99  Usually dispatched in 11 to 12 days.
# 401192             Rucksacks     ₹99  Usually dispatched in 11 to 12 days.
# 401193             Rucksacks     ₹99  Usually dispatched in 11 to 12 days.
# 401194             Rucksacks     ₹99  Usually dispatched in 11 to 12 days.
# 401195             Rucksacks     ₹99  Usually dispatched in 11 to 12 days.
# 401196             Rucksacks     ₹99  Usually dispatched in 11 to 12 days.
# 401198             Rucksacks     ₹99  Usually dispatched in 11 to 12 days.
# 478074            Sunglasses   ₹2.99    Usually dispatched in 6 to 7 days.
# 478075            Sunglasses   ₹2.99    Usually dispatched in 6 to 7 days.
# 506485        Travel Duffles     ₹99  Usually dispatched in 11 to 12 days.
# 506486        Travel Duffles     ₹99  Usually dispatched in 11 to 12 days.
# 506487        Travel Duffles     ₹99  Usually dispatched in 11 to 12 days.
# 506488        Travel Duffles     ₹99  Usually dispatched in 11 to 12 days.
# 506489        Travel Duffles     ₹99  Usually dispatched in 11 to 12 days.
# 506490        Travel Duffles     ₹99  Usually dispatched in 11 to 12 days.
# 506492        Travel Duffles     ₹99  Usually dispatched in 11 to 12 days.
#
#        Discount Price Actual Price
# 224204           ₹765       ₹1,200
# 277756         ₹1,790       ₹2,166
# 284642         ₹1,790       ₹2,166
# 286032         ₹1,790       ₹2,166
# 286033         ₹1,690       ₹2,045
# 299759         ₹2,126       ₹2,573
# 368276         ₹1,790       ₹2,166
# 401191         ₹6,796      ₹20,388
# 401192         ₹3,945      ₹11,835
# 401193         ₹3,079       ₹9,237
# 401194         ₹1,714       ₹5,142
# 401195         ₹2,538       ₹7,614
# 401196         ₹1,317       ₹3,951
# 401198         ₹1,527       ₹4,581
# 478074           ₹681       ₹1,022
# 478075           ₹696       ₹1,043
# 506485         ₹6,695      ₹20,085
# 506486        ₹10,376      ₹31,128
# 506487        ₹14,615      ₹43,845
# 506488        ₹11,256      ₹33,768
# 506489        ₹15,348      ₹46,044
# 506490        ₹14,759      ₹44,277
# 506492        ₹11,061      ₹33,183

# %%
# droping the filter for rupee sign for which we used .str.contains method to filter out.
df_dropped_3 = df_dropped_2.drop(df_dropped_2[df_dropped_2['Ratings'].str.contains('₹')].index)
df_dropped_3
# Out:
#                                                      Name     Main Category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551579  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             Sub-category Ratings No. Of Ratings Discount Price Actual Price
# 0       Air Conditioners     4.2          2,255        ₹32,999      ₹58,990
# 1       Air Conditioners     4.2          2,948        ₹46,490      ₹75,990
# 2       Air Conditioners     4.2          1,206        ₹34,490      ₹61,990
# 3       Air Conditioners     4.0             69        ₹37,990      ₹68,990
# 4       Air Conditioners     4.1            630        ₹34,490      ₹67,790
# ...                  ...     ...            ...            ...          ...
# 551579              Yoga     4.6              6           ₹711         ₹999
# 551580              Yoga     3.2              9         ₹3,449       ₹4,599
# 551581              Yoga     2.0              2         ₹1,199       ₹1,999
# 551582              Yoga     4.0              1         ₹1,199       ₹1,999
# 551584              Yoga     4.6              5         ₹1,039       ₹1,299
#
# [340657 rows x 7 columns]

# %%
# Then we check again for unique values of ratings by using .unique method
df_dropped_3.Ratings.unique()
# Out:
# array(['4.2', '4.0', '4.1', '4.3', '3.9', '3.8', '3.5', '4.6', '3.3',
#        '3.4', '3.7', '2.9', '5.0', '4.4', '3.6', '2.7', '4.5', '3.0',
#        '3.1', '4.8', '4.7', '3.2', '2.5', '1.0', '2.6', '2.8', '1.7',
#        'Get', '1.8', '2.4', '4.9', '2.2', '1.6', '1.9', '2.3', '2.0',
#        '1.4', '2.1', 'FREE', '1.2', '1.3', '1.5', '1.1'], dtype=object)

# %%
# now let's filter out the Get & Free from this dataset using conditional filtering
df_dropped_3[(df_dropped_3.Ratings == 'Get') | (df_dropped_3.Ratings == 'FREE')]
# Out:
#                                                      Name     Main Category  \
# 437     Daikin 1.8 Ton 3 Star Inverter Split Ac (Coppe...        appliances
# 473     Master Electronic provides Window AC 3-Star 1....        appliances
# 474     Master Electronic provides 1.5 Ton 3 Star Dust...        appliances
# 475     Master Electronics Provides 1 Ton 3 Star Inver...        appliances
# 488               1.5 Ton 5 Star Inverter Split AC, White        appliances
# ...                                                   ...               ...
# 551502                                Puma Men Sweatshirt  sports & fitness
# 551504  Monte Carlo Hood Full Sleeve Sweatshirt Womens...  sports & fitness
# 551541                                  Adidas Men's Flat  sports & fitness
# 551550  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 551551  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
#
#             Sub-category Ratings           No. Of Ratings Discount Price  \
# 437     Air Conditioners     Get    Only 2 left in stock.        ₹59,979
# 473     Air Conditioners     Get    Only 1 left in stock.        ₹36,999
# 474     Air Conditioners     Get    Only 1 left in stock.        ₹36,999
# 475     Air Conditioners     Get    Only 1 left in stock.        ₹46,999
# 488     Air Conditioners     Get    Only 2 left in stock.        ₹45,000
# ...                  ...     ...                      ...            ...
# 551502              Yoga     Get  FREE Delivery by Amazon      ₹3,712.10
# 551504              Yoga     Get  FREE Delivery by Amazon         ₹1,917
# 551541              Yoga     Get  FREE Delivery by Amazon      ₹1,429.60
# 551550              Yoga     Get  FREE Delivery by Amazon           ₹699
# 551551              Yoga     Get  FREE Delivery by Amazon        ₹651.01
#
#        Actual Price
# 437         ₹72,900
# 473         ₹39,999
# 474         ₹39,666
# 475         ₹49,666
# 488         ₹50,000
# ...             ...
# 551502       ₹4,999
# 551504       ₹1,945
# 551541       ₹3,599
# 551550       ₹2,199
# 551551       ₹2,399
#
# [5694 rows x 7 columns]

# %%
# After doing the conditional filtering for Get and free, now we can pass it into a new variable.
df_dropped_4 = df_dropped_3[(df_dropped_3.Ratings != 'Get') & (df_dropped_3.Ratings != 'FREE')]
df_dropped_4
# Out:
#                                                      Name     Main Category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551579  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             Sub-category Ratings No. Of Ratings Discount Price Actual Price
# 0       Air Conditioners     4.2          2,255        ₹32,999      ₹58,990
# 1       Air Conditioners     4.2          2,948        ₹46,490      ₹75,990
# 2       Air Conditioners     4.2          1,206        ₹34,490      ₹61,990
# 3       Air Conditioners     4.0             69        ₹37,990      ₹68,990
# 4       Air Conditioners     4.1            630        ₹34,490      ₹67,790
# ...                  ...     ...            ...            ...          ...
# 551579              Yoga     4.6              6           ₹711         ₹999
# 551580              Yoga     3.2              9         ₹3,449       ₹4,599
# 551581              Yoga     2.0              2         ₹1,199       ₹1,999
# 551582              Yoga     4.0              1         ₹1,199       ₹1,999
# 551584              Yoga     4.6              5         ₹1,039       ₹1,299
#
# [334963 rows x 7 columns]

# %%
# Typecasting Ratings to Decimal so that we can perform the desired operations when needed.
df_dropped_4['Ratings'] = df_dropped_4['Ratings'].astype('float64')
df_dropped_4.dtypes
# Out:
# Name               object
# Main Category      object
# Sub-category       object
# Ratings           float64
# No. Of Ratings     object
# Discount Price     object
# Actual Price       object
# dtype: object

# %%
# # To check for unique values for No of ratings 
df_dropped_4['No. Of Ratings'].unique()
# Out:
# array(['2,255', '2,948', '1,206', ..., '55,051', '3,329', '7,141'],
#       dtype=object)

# %%
# We cannot convert No. Of Ratings field from Object to Integer when the records have comma sign
# We have to get rid of these comma signs, and replace them with empty string
df_dropped_4['No. Of Ratings'] = df_dropped_4['No. Of Ratings'].str.replace(',','')
df_dropped_4
# Out:
#                                                      Name     Main Category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551579  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             Sub-category  Ratings No. Of Ratings Discount Price Actual Price
# 0       Air Conditioners      4.2           2255        ₹32,999      ₹58,990
# 1       Air Conditioners      4.2           2948        ₹46,490      ₹75,990
# 2       Air Conditioners      4.2           1206        ₹34,490      ₹61,990
# 3       Air Conditioners      4.0             69        ₹37,990      ₹68,990
# 4       Air Conditioners      4.1            630        ₹34,490      ₹67,790
# ...                  ...      ...            ...            ...          ...
# 551579              Yoga      4.6              6           ₹711         ₹999
# 551580              Yoga      3.2              9         ₹3,449       ₹4,599
# 551581              Yoga      2.0              2         ₹1,199       ₹1,999
# 551582              Yoga      4.0              1         ₹1,199       ₹1,999
# 551584              Yoga      4.6              5         ₹1,039       ₹1,299
#
# [334963 rows x 7 columns]

# %%
# remove all string values from a column using regex
df_dropped_4['No. Of Ratings'] = df_dropped_4['No. Of Ratings'].replace('[a-zA-Z]', np.nan, regex=True)
df_dropped_4
# Out:
#                                                      Name     Main Category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551579  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             Sub-category  Ratings No. Of Ratings Discount Price Actual Price
# 0       Air Conditioners      4.2           2255        ₹32,999      ₹58,990
# 1       Air Conditioners      4.2           2948        ₹46,490      ₹75,990
# 2       Air Conditioners      4.2           1206        ₹34,490      ₹61,990
# 3       Air Conditioners      4.0             69        ₹37,990      ₹68,990
# 4       Air Conditioners      4.1            630        ₹34,490      ₹67,790
# ...                  ...      ...            ...            ...          ...
# 551579              Yoga      4.6              6           ₹711         ₹999
# 551580              Yoga      3.2              9         ₹3,449       ₹4,599
# 551581              Yoga      2.0              2         ₹1,199       ₹1,999
# 551582              Yoga      4.0              1         ₹1,199       ₹1,999
# 551584              Yoga      4.6              5         ₹1,039       ₹1,299
#
# [334963 rows x 7 columns]

# %%
## Typecasting No. Of Ratings to Integer (first to float because the column seems to have a mixture of integer and decimal)
df_dropped_4['No. Of Ratings'] = df_dropped_4['No. Of Ratings'].astype('float64')
df_dropped_4['No. Of Ratings'] = df_dropped_4['No. Of Ratings'].astype('int64')
df_dropped_4.dtypes
# Out:
# Name               object
# Main Category      object
# Sub-category       object
# Ratings           float64
# No. Of Ratings      int64
# Discount Price     object
# Actual Price       object
# dtype: object

# %%
# To check for unique values of discount price
df_dropped_4['Discount Price'].unique
# Out:
# <bound method Series.unique of 0         ₹32,999
# 1         ₹46,490
# 2         ₹34,490
# 3         ₹37,990
# 4         ₹34,490
#            ...
# 551579       ₹711
# 551580     ₹3,449
# 551581     ₹1,199
# 551582     ₹1,199
# 551584     ₹1,039
# Name: Discount Price, Length: 334963, dtype: object>

# %%
# We cannot convert Discount Price field from Object to Integer/Float when the records have comma sign and the rupee sign
# We have to get rid of these signs, and replace them with empty string
df_dropped_4['Discount Price'] = df_dropped_4['Discount Price'].str.replace(',','')
df_dropped_4['Discount Price'] = df_dropped_4['Discount Price'].str.replace('₹', '')

# %%
### Typecasting Discount Price to Decimal so that we can perform the desired operations when needed.
df_dropped_4['Discount Price'] = df_dropped_4['Discount Price'].astype('float64')
df_dropped_4.dtypes
# Out:
# Name               object
# Main Category      object
# Sub-category       object
# Ratings           float64
# No. Of Ratings      int64
# Discount Price    float64
# Actual Price       object
# dtype: object

# %%
#  To check for unique values of ratings 
df_dropped_4['Actual Price'].unique()
# Out:
# array(['₹58,990', '₹75,990', '₹61,990', ..., '₹7,484', '₹2,234',
#        '₹32,120'], dtype=object)

# %%
# We cannot convert Actual Price field from Object to Integer/Float when the records have comma sign and the rupee sign
# We have to get rid of these signs, and replace them with empty string
df_dropped_4['Actual Price'] = df_dropped_4['Actual Price'].str.replace(',','')
df_dropped_4['Actual Price'] = df_dropped_4['Actual Price'].str.replace('₹','')

# %%
### Typecasting  Actual Price to Integer/float so that we can perform the desired operations when needed.
df_dropped_4['Actual Price'] = df_dropped_4['Actual Price'].astype('float64')
df_dropped_4.dtypes
# Out:
# Name               object
# Main Category      object
# Sub-category       object
# Ratings           float64
# No. Of Ratings      int64
# Discount Price    float64
# Actual Price      float64
# dtype: object

# %%
### Lets look at our cleaned dataset so far...
df_dropped_5 = df_dropped_4
df_dropped_5

# %%
# checking for duplicated values in our dataset
df_dropped_5.duplicated().any()
# Out:
# True

# %%
# droping the duplicates in our dataset and passing it into a new variable.
df_dropped_5 = df_dropped_5.drop_duplicates()

# %%
# After droping the duplicates, we can confirm if their is still duplicates.
# As we can see below it's False, meaning their is no more duplicates in our dataset.
df_dropped_5.duplicated().any()
# Out:
# False

# %%
### NOW TO ATTEND TO THE DATA ANALYSIS QUESTIONS FOR INSIGHTS INTO THE DATA...

# %% [markdown]
# ## Phase 5: Data mining (uncovering insights)
#
# #### We need to carry out data manipulation to find out the following information:
#
# * What are the most popular product categories?
# * What are the most popular product sub-categories?
# * What are the most popular products by ratings?
# * What are the most popular products by pricing strategy?
# * What are the top selling products?
# * What are the least selling products?

# %%
### Lets add new columns that we might need for our Business Analysis (BI)
df_dropped_5 = df_dropped_4
df_dropped_5['Total sales'] = df_dropped_5['No. Of Ratings']*df_dropped_5['Discount Price']
df_dropped_5['Percentage Discount'] = (df_dropped_5['Actual Price']-df_dropped_5['Discount Price'])/df_dropped_5['Actual Price']*100
df_dropped_5
# Out:
#                                                      Name     Main Category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551579  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#             Sub-category  Ratings  No. Of Ratings  Discount Price  \
# 0       Air Conditioners      4.2            2255         32999.0
# 1       Air Conditioners      4.2            2948         46490.0
# 2       Air Conditioners      4.2            1206         34490.0
# 3       Air Conditioners      4.0              69         37990.0
# 4       Air Conditioners      4.1             630         34490.0
# ...                  ...      ...             ...             ...
# 551579              Yoga      4.6               6           711.0
# 551580              Yoga      3.2               9          3449.0
# 551581              Yoga      2.0               2          1199.0
# 551582              Yoga      4.0               1          1199.0
# 551584              Yoga      4.6               5          1039.0
#
#         Actual Price  Total sales  Percentage Discount
# 0            58990.0   74412745.0            44.060010
# 1            75990.0  137052520.0            38.820897
# 2            61990.0   41594940.0            44.361994
# 3            68990.0    2621310.0            44.934048
# 4            67790.0   21728700.0            49.122289
# ...              ...          ...                  ...
# 551579         999.0       4266.0            28.828829
# 551580        4599.0      31041.0            25.005436
# 551581        1999.0       2398.0            40.020010
# 551582        1999.0       1199.0            40.020010
# 551584        1299.0       5195.0            20.015396
#
# [334963 rows x 9 columns]

# %%
# Carry out one final summary statistics
pd.set_option("display.max.rows", None) # make sure pandas does not hide any rows
df_dropped_5.describe(include='all')
# Out:
#                                 Name Main Category Sub-category  \
# count                         334963        334963       334963
# unique                        237352            20          112
# top     Red Tape Men's Walking Shoes   accessories     Clothing
# freq                             243         62869        16940
# mean                             NaN           NaN          NaN
# std                              NaN           NaN          NaN
# min                              NaN           NaN          NaN
# 25%                              NaN           NaN          NaN
# 50%                              NaN           NaN          NaN
# 75%                              NaN           NaN          NaN
# max                              NaN           NaN          NaN
#
#               Ratings  No. Of Ratings  Discount Price  Actual Price  \
# count   334963.000000   334963.000000    3.349630e+05  3.349630e+05
# unique            NaN             NaN             NaN           NaN
# top               NaN             NaN             NaN           NaN
# freq              NaN             NaN             NaN           NaN
# mean         3.814368      853.864540    1.759009e+03  3.298855e+04
# std          0.754169     8890.977903    6.394477e+03  1.710586e+07
# min          1.000000        1.000000    8.000000e+00  1.000000e+01
# 25%          3.500000        4.000000    3.590000e+02  9.000000e+02
# 50%          3.900000       20.000000    5.990000e+02  1.499000e+03
# 75%          4.200000      131.000000    1.199000e+03  2.799000e+03
# max          5.000000   589547.000000    1.249990e+06  9.900000e+09
#
#          Total sales  Percentage Discount
# count   3.349630e+05        334963.000000
# unique           NaN                  NaN
# top              NaN                  NaN
# freq             NaN                  NaN
# mean    2.078330e+06            50.953023
# std     3.920811e+07            21.474900
# min     1.900000e+01             0.000529
# 25%     2.786000e+03            36.436436
# 50%     1.427400e+04            53.066551
# 75%     9.980000e+04            67.967968
# max     9.196933e+09            99.999994

# %%
df_dropped_5['Main Category'].unique()
# Out:
# array(['appliances', 'car & motorbike', 'tv, audio & cameras',
#        'sports & fitness', 'grocery & gourmet foods', 'home & kitchen',
#        'pet supplies', 'stores', 'toys & baby products', "kids' fashion",
#        'bags & luggage', 'accessories', "women's shoes",
#        'beauty & health', "men's shoes", "women's clothing",
#        'industrial supplies', "men's clothing", 'music',
#        'home, kitchen, pets'], dtype=object)

# %%
len(df_dropped_5['Main Category'].unique())
# Out:
# 20

# %%
df_dropped_5['Sub-category'].unique()
# Out:
# array(['Air Conditioners', 'All Appliances',
#        'All Car & Motorbike Products', 'All Electronics',
#        'All Exercise & Fitness', 'All Grocery & Gourmet Foods',
#        'All Home & Kitchen', 'All Pet Supplies',
#        'All Sports, Fitness & Outdoors', 'Amazon Fashion',
#        'Baby Bath, Skin & Grooming', 'Baby Fashion', 'Baby Products',
#        'Backpacks', 'Badminton', 'Bags & Luggage', 'Ballerinas',
#        'Beauty & Grooming', 'Bedroom Linen', 'Camera Accessories',
#        'Cameras', 'Camping & Hiking', 'Car & Bike Care',
#        'Car Accessories', 'Car Electronics', 'Car Parts',
#        'Cardio Equipment', 'Casual Shoes', 'Clothing',
#        'Coffee, Tea & Beverages', 'Cricket', 'Cycling', 'Diapers',
#        'Diet & Nutrition', 'Dog supplies', 'Ethnic Wear',
#        'Fashion & Silver Jewellery', 'Fashion Sales & Deals',
#        'Fashion Sandals', 'Fitness Accessories', 'Football',
#        'Formal Shoes', 'Furniture', 'Garden & Outdoors',
#        'Gold & Diamond Jewellery', 'Handbags & Clutches', 'Headphones',
#        'Health & Personal Care', 'Heating & Cooling Appliances',
#        'Home Audio & Theater', 'Home Décor', 'Home Entertainment Systems',
#        'Home Furnishing', 'Home Improvement', 'Home Storage',
#        'Household Supplies', 'Indoor Lighting',
#        'Industrial & Scientific Supplies', 'Innerwear',
#        'International Toy Store', 'Janitorial & Sanitation Supplies',
#        'Jeans', 'Jewellery', "Kids' Clothing", "Kids' Fashion",
#        "Kids' Shoes", "Kids' Watches", 'Kitchen & Dining',
#        'Kitchen & Home Appliances', 'Kitchen Storage & Containers',
#        'Lab & Scientific', 'Lingerie & Nightwear', 'Luxury Beauty',
#        'Make-up', "Men's Fashion", 'Motorbike Accessories & Parts',
#        'Musical Instruments & Professional Audio', 'Nursing & Feeding',
#        'Personal Care Appliances', 'Refrigerators',
#        'Refurbished & Open Box', 'Rucksacks', 'Running', 'School Bags',
#        'Security Cameras', 'Sewing & Craft Supplies', 'Shirts', 'Shoes',
#        'Snack Foods', 'Speakers', 'Sports Shoes', 'Sportswear',
#        'STEM Toys Store', 'Strength Training', 'Strollers & Prams',
#        'Suitcases & Trolley Bags', 'Sunglasses', 'T-shirts & Polos',
#        'Televisions', 'Test, Measure & Inspect', 'The Designer Boutique',
#        'Toys & Games', 'Toys Gifting Store', 'Travel Accessories',
#        'Travel Duffles', 'Value Bazaar', 'Wallets', 'Washing Machines',
#        'Watches', 'Western Wear', "Women's Fashion", 'Yoga'], dtype=object)

# %%
len(df_dropped_5['Sub-category'].unique())
# Out:
# 112

# %%
# Let's look at the number of sales per product categories for all categories
sales_per_cat = df_dropped_5.groupby('Main Category', as_index=False)[['No. Of Ratings']].sum() \
                    .sort_values('No. Of Ratings',ascending=False)
sales_per_cat
# Out:
#               Main Category  No. Of Ratings
# 17      tv, audio & cameras       178329604
# 15                   stores        17913789
# 1                appliances        16579049
# 18         women's clothing        13216389
# 16     toys & baby products        12439096
# 0               accessories        10465276
# 3           beauty & health         9246838
# 6            home & kitchen         8854606
# 11              men's shoes         4778683
# 10           men's clothing         3899554
# 14         sports & fitness         2592698
# 5   grocery & gourmet foods         1384302
# 4           car & motorbike         1363086
# 9             kids' fashion         1331624
# 2            bags & luggage         1170099
# 8       industrial supplies          917570
# 13             pet supplies          847066
# 19            women's shoes          456452
# 12                    music          227200
# 7       home, kitchen, pets              47

# %%
# What are the most popular product categories?
popular_product_cat = df_dropped_5.groupby('Main Category', as_index=False)[['No. Of Ratings']].sum() \
                        .sort_values('No. Of Ratings',ascending=False).head(10)
popular_product_cat
# Out:
#            Main Category  No. Of Ratings
# 17   tv, audio & cameras       178329604
# 15                stores        17913789
# 1             appliances        16579049
# 18      women's clothing        13216389
# 16  toys & baby products        12439096
# 0            accessories        10465276
# 3        beauty & health         9246838
# 6         home & kitchen         8854606
# 11           men's shoes         4778683
# 10        men's clothing         3899554

# %%
### Lets list out the product categories...
list(popular_product_cat['Main Category'])
# Out:
# ['tv, audio & cameras',
#  'stores',
#  'appliances',
#  "women's clothing",
#  'toys & baby products',
#  'accessories',
#  'beauty & health',
#  'home & kitchen',
#  "men's shoes",
#  "men's clothing"]

# %% [markdown]
# ### From the code above, we can see that the top 10 most popular product categories are:
# * tv, audio & cameras
# * stores
# * appliances
# * women's clothing
# * toys & baby products
# * accessories
# * beauty & health
# * home & kitchen
# * men's shoes, and
# * men's clothing

# %%
# What are the most popular product sub categories?
popular_product_sub_cat = df_dropped_5.groupby('Sub-category', as_index=False)[['No. Of Ratings']] \
                                .sum().sort_values('No. Of Ratings',ascending=False).head(15)
popular_product_sub_cat
# Out:
#                   Sub-category  No. Of Ratings
# 3              All Electronics        81135801
# 46                  Headphones        33547622
# 20                     Cameras        20010709
# 19          Camera Accessories        19396099
# 51  Home Entertainment Systems        15834117
# 74               Men's Fashion         9755338
# 1               All Appliances         7549783
# 68   Kitchen & Home Appliances         6440823
# 9               Amazon Fashion         6131443
# 15              Bags & Luggage         6014798
# 28                    Clothing         5869166
# 12               Baby Products         5825007
# 90                    Speakers         5719127
# 6           All Home & Kitchen         3589386
# 47      Health & Personal Care         3524761

# %%
# let's list out the product sub-categories 
list(popular_product_sub_cat['Sub-category'])
# Out:
# ['All Electronics',
#  'Headphones',
#  'Cameras',
#  'Camera Accessories',
#  'Home Entertainment Systems',
#  "Men's Fashion",
#  'All Appliances',
#  'Kitchen & Home Appliances',
#  'Amazon Fashion',
#  'Bags & Luggage',
#  'Clothing',
#  'Baby Products',
#  'Speakers',
#  'All Home & Kitchen',
#  'Health & Personal Care']

# %% [markdown]
# ### From the above code we can see the 15 most popular sub-categories are:
#
# * 'All Electronics',
# * 'Headphones',
# * 'Cameras',
# * 'Camera Accessories',
# * 'Home Entertainment Systems',
# * "Men's Fashion",
# * 'All Appliances',
# * 'Kitchen & Home Appliances',
# * 'Amazon Fashion',
# * 'Bags & Luggage
# * 'Clothing',
# * 'Baby Products',
# * 'Speakers',
# * 'All Home & Kitchen',
# * 'Health & Personal Care'

# %%
# What are the most popular products by ratings?
pd.set_option("display.max.rows", 10) # reduce the number of records shown to default
pop_prod_by_rat = df_dropped_5.sort_values(['Total sales', 'No. Of Ratings','Ratings'], ascending = False).head(100)
pop_prod_by_rat
# Out:
#                                                      Name  \
# 66723   SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...
# 79485   SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...
# 68452   SanDisk 512GB Ultra MicroSDXC UHS-I Memory Car...
# 62204   SanDisk Extreme Pro SD UHS I 1TB Card for 4K V...
# 72681   SanDisk Extreme Pro SD UHS I 1TB Card for 4K V...
# ...                                                   ...
# 498321  Mi 100 cm (40 inches) Horizon Edition Full HD ...
# 66161   SanDisk Extreme SDXC, SDXVF 256GB, V30, U3, C1...
# 78638   SanDisk Extreme SDXC, SDXVF 256GB, V30, U3, C1...
# 12043   OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 17390   Western Digital WD 5TB My Passport Portable Ha...
#
#               Main Category        Sub-category  Ratings  No. Of Ratings  \
# 66723   tv, audio & cameras  Camera Accessories      4.3          589547
# 79485   tv, audio & cameras             Cameras      4.3          589547
# 68452   tv, audio & cameras  Camera Accessories      4.3          589547
# 62204   tv, audio & cameras  Camera Accessories      4.5          215311
# 72681   tv, audio & cameras             Cameras      4.5          215311
# ...                     ...                 ...      ...             ...
# 498321  tv, audio & cameras         Televisions      4.2           34286
# 66161   tv, audio & cameras  Camera Accessories      4.5          215311
# 78638   tv, audio & cameras             Cameras      4.5          215311
# 12043   tv, audio & cameras     All Electronics      4.2           59253
# 17390   tv, audio & cameras     All Electronics      4.4           74559
#
#         Discount Price  Actual Price   Total sales  Percentage Discount
# 66723          15600.0       22289.0  9.196933e+09            30.010319
# 79485          15600.0       22289.0  9.196933e+09            30.010319
# 68452           8022.0       15000.0  4.729346e+09            46.520000
# 62204          17999.0       51000.0  3.875383e+09            64.707843
# 72681          17999.0       51000.0  3.875383e+09            64.707843
# ...                ...           ...           ...                  ...
# 498321         21999.0       29999.0  7.542577e+08            26.667556
# 66161           3499.0       10500.0  7.533732e+08            66.676190
# 78638           3499.0       10500.0  7.533732e+08            66.676190
# 12043          12490.0       15990.0  7.400700e+08            21.888680
# 17390           9899.0       20000.0  7.380595e+08            50.505000
#
# [100 rows x 9 columns]

# %%
# let's list out the popular products by ratings
list(pop_prod_by_rat['Name'])
# Out:
# ['SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-400G-GN6MA) with Adapter',
#  'SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-400G-GN6MA) with Adapter',
#  'SanDisk 512GB Ultra MicroSDXC UHS-I Memory Card - 100MB/s, C10, U1, Full HD, A1, Micro SD Card - SDSQUAR-512G-GN6MN',
#  'SanDisk Extreme Pro SD UHS I 1TB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#  'SanDisk Extreme Pro SD UHS I 1TB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#  'Redmi Note 10S (Cosmic Purple, 6GB RAM, 128GB Storage)\xa0 - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen R...',
#  'Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen Rep...',
#  'Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Redmi 164 cm (65 inches) 4K Ultra HD Android Smart LED TV X65 | L65M6-RA (Black)',
#  'Redmi 164 cm (65 inches) 4K Ultra HD Android Smart LED TV X65 | L65M6-RA (Black)',
#  'Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9A Sport (Carbon Black, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 8GB RAM, 128GB Storage)',
#  'Samsung Galaxy M12 (Black,6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM, 128GB Storage)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM, 128GB Storage)',
#  'Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'SanDisk Extreme Pro SD UHS I 512GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#  'SanDisk Extreme Pro SD UHS I 512GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#  'SanDisk 256GB Class 10 MicroSD Card with Adapter (SDSQUAR-256G-GN6MA)',
#  'SanDisk 256GB Class 10 MicroSD Card with Adapter (SDSQUAR-256G-GN6MA)',
#  'Redmi 139 cm (55 inches) 4K Ultra HD Android Smart LED TV X55 | L55M6-RA (Black)',
#  'Redmi 139 cm (55 inches) 4K Ultra HD Android Smart LED TV X55 | L55M6-RA (Black)',
#  'Redmi 139 cm (55 inches) 4K Ultra HD Android Smart LED TV X55 | L55M6-RA (Black)',
#  'Apple iPhone 12 (128GB) - Green',
#  'Apple iPhone 12 (128GB) - Black',
#  'Fitbit FB507RGPK Versa 2 Health & Fitness Smartwatch with Heart Rate, Music, Alexa Built-in, Sleep & Swim Tracking, Petal/...',
#  'Apple iPhone 12 (64GB) - Black',
#  'Apple iPhone 12 (64GB) - Blue',
#  'Apple iPhone 12 (64GB) - White',
#  'Fitbit FB507BKBK Versa 2 Health & Fitness Smartwatch with Heart Rate, Music, Alexa Built-in, Sleep & Swim Tracking, Black/...',
#  'Redmi 126 cm (50 inches) 4K Ultra HD Android Smart LED TV X50 | L50M6-RA (Black)',
#  'Redmi 126 cm (50 inches) 4K Ultra HD Android Smart LED TV X50 | L50M6-RA (Black)',
#  'Redmi 126 cm (50 inches) 4K Ultra HD Android Smart LED TV X50 | L50M6-RA (Black)',
#  'Redmi 108 cm (43 inches) 4K Ultra HD Android Smart LED TV X43 | L43R7-7AIN (Black)',
#  'Redmi 108 cm (43 inches) 4K Ultra HD Android Smart LED TV X43 | L43R7-7AIN (Black)',
#  'Redmi 108 cm (43 inches) 4K Ultra HD Android Smart LED TV X43 | L43R7-7AIN (Black)',
#  'TOZO T6 True Wireless Earbuds Bluetooth Headphones Touch Control with Wireless Charging Case IPX8 Waterproof Stereo Earpho...',
#  'TOZO T6 True Wireless Earbuds Bluetooth Headphones Touch Control with Wireless Charging Case IPX8 Waterproof Stereo Earpho...',
#  'Redmi Note 9 (Arctic White, 4GB RAM, 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#  'Redmi 108 cm (43 inches) Android 11 Series Full HD Smart LED TV L43M6-RA/L43M7-RA (Black)',
#  'Redmi 108 cm (43 inches) Android 11 Series Full HD Smart LED TV L43M6-RA/L43M7-RA (Black)',
#  'MI 138.8 cm (55 inches) 5X Series 4K Ultra HD LED Smart Android TV L55M6-ES (Grey)',
#  'MI 138.8 cm (55 inches) 5X Series 4K Ultra HD LED Smart Android TV L55M6-ES (Grey)',
#  'MI 138.8 cm (55 inches) 5X Series 4K Ultra HD LED Smart Android TV L55M6-ES (Grey)',
#  'SanDisk 128GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-128G-GN6MA)',
#  'SanDisk 128GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-128G-GN6MA)',
#  'Apple iPhone 13 (256GB) - Blue',
#  'Apple iPhone 13 (256GB) - Midnight',
#  'SanDisk 2TB Extreme Pro Portable SSD 2000MB/s R/W, Upto 2 Meter Drop Protection with IP55 Water and dust Resistance, Metal...',
#  'Wakefit Mattress | 10 Years Warranty | Orthopedic Mattress, Mattress Double Bed, Memory Foam Mattress, 8-Inch Bed Mattres...',
#  'Wyze Labs Cam Pan 1080p Tilt/Zoom WiFi Indoor Smart Home Camera',
#  'SanDisk 2TB Extreme Portable SSD 1050MB/s R, 1000MB/s W,Upto 2 Meter Drop Protection with IP55 Water/dust Resistance, HW E...',
#  'SanDisk Extreme Pro SD UHS I 256GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#  'SanDisk Extreme Pro SD UHS I 256GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#  'Huggies Wonder Pants, Monthly Box Pack Diapers, Extra Large (XL) , 112 Count & Diapers Sumo Pack, Extra Large (168 Count)',
#  'Wyze Labs Cam 1080p HD Indoor Wireless Smart Home Camera with Night Vision, 2-Way Audio, Compatible with Alexa, Pack of 2',
#  'MI 125.7 cm (50 inches) 5X Series 4K Ultra HD LED Smart Android TV L50M6-ES (Grey)',
#  'MI 125.7 cm (50 inches) 5X Series 4K Ultra HD LED Smart Android TV L50M6-ES (Grey)',
#  'Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM, 128GB Storage) with No Cost EMI & Additional Exchange Offers',
#  'Samsung Galaxy S20 FE 5G (Cloud Mint, 8GB RAM, 128GB Storage)',
#  'Apple iPhone 13 (128GB) - Midnight',
#  'Apple iPhone 13 (128GB) - Starlight',
#  'Apple iPhone 13 (128GB) - Blue',
#  'Apple iPhone 13 (128GB) - Blue',
#  'OnePlus 108 cm (43 inches) Y Series Full HD Smart Android LED TV 43 Y1S (Black)',
#  'OnePlus 108 cm (43 inches) Y Series Full HD Smart Android LED TV 43 Y1S (Black)',
#  'OnePlus 108 cm (43 inches) Y Series Full HD Smart Android LED TV 43 Y1S (Black)',
#  'Sony WH-1000XM4 Industry Leading Wireless Noise Cancellation Bluetooth Over Ear Headphones with Mic for Phone Calls, 30 Ho...',
#  'Sony WH-1000XM4 Industry Leading Wireless Noise Cancellation Bluetooth Over Ear Headphones with Mic for Phone Calls, 30 Ho...',
#  'Sony WH-1000XM4 Industry Leading Wireless Noise Cancellation Bluetooth Over Ear Headphones with Mic for Phone Calls, 30 Ho...',
#  'Sony WH-1000XM4 Wireless Premium Noise Cancelling Bluetooth Over Ear Headphones with Mic for Phone Calls, Silver',
#  'boAt Airdopes 121 PRO True Wireless in Ear Earbuds Signature Sound(Royal Blue) & Xtend/Xtend RTL Smartwatch with Alexa Bui...',
#  'Redmi 10 Prime (Astral White 4GB RAM 64GB ROM |Helio G88 with extendable RAM Upto 2GB |FHD+ 90Hz Adaptive Sync Display)',
#  'Anker Soundcore 2 Portable Bluetooth Speaker With Better Bass, 24-Hour Playtime, 66Ft Bluetooth Range, Ipx5 Water Resistan...',
#  "Hey Dude Men's Wally Sox Loafer",
#  'Mi 11X Cosmic Black 6GB RAM 128GB ROM Storage 5G | SD 870 | DisplayMate A+ rated 120Hz E4 AMOLED | 48MP Sony sensor',
#  'JBL Flip 4, Wireless Portable Bluetooth Speaker with Mic, Signature Sound with Bass Radiator, Vibrant Colors with Rugged F...',
#  'JBL Flip 4, Wireless Portable Bluetooth Speaker with Mic, Signature Sound with Bass Radiator, Vibrant Colors with Rugged F...',
#  'JBL Flip 4, Wireless Portable Bluetooth Speaker with Mic, Signature Sound with Bass Radiator, Vibrant Colors with Rugged F...',
#  'Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery',
#  "Skechers Men's Energy Afterburn Lace-Up Sneaker",
#  "Skechers Men's Energy Afterburn Lace-Up Sneaker",
#  'MI 108 cm (43 inches) 5A Series Full HD Smart Android LED TV L43M7-EAIN (Black)',
#  'MI 108 cm (43 inches) 5A Series Full HD Smart Android LED TV L43M7-EAIN (Black)',
#  'MI 108 cm (43 inches) 5A Series Full HD Smart Android LED TV L43M7-EAIN (Black)',
#  'Redmi Note 11 (Horizon Blue, 6GB RAM, 128GB Storage)|90Hz FHD+ AMOLED Display | Qualcomm® Snapdragon™ 680-6nm | 33W Charge...',
#  'boAt Rockerz 330ANC Bluetooth Neckband in Ear Earphones (Gunmetal Black) & Wave Call Smart Watch, Smart Talk (Active Blac...',
#  'Samsung Galaxy M32 (Light Blue, 4GB RAM, 64GB | FHD+ sAMOLED 90Hz Display | 6000mAh Battery | 64MP Quad Camera',
#  'MI 100 cm (40 inches) 5A Series Full HD Smart Android LED TV L40M7-EAIN (Black)',
#  'Mi 100 cm (40 inches) Horizon Edition Full HD Android LED TV 4A | L40M6-EI (Black)',
#  'MI 100 cm (40 inches) 5A Series Full HD Smart Android LED TV L40M7-EAIN (Black)',
#  'Mi 100 cm (40 inches) Horizon Edition Full HD Android LED TV 4A | L40M6-EI (Black)',
#  'MI 100 cm (40 inches) 5A Series Full HD Smart Android LED TV L40M7-EAIN (Black)',
#  'Mi 100 cm (40 inches) Horizon Edition Full HD Android LED TV 4A | L40M6-EI (Black)',
#  'SanDisk Extreme SDXC, SDXVF 256GB, V30, U3, C10, UHS-I, 90MB/s R, 60MB/s W, for 4K Video',
#  'SanDisk Extreme SDXC, SDXVF 256GB, V30, U3, C10, UHS-I, 90MB/s R, 60MB/s W, for 4K Video',
#  'OPPO A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Western Digital WD 5TB My Passport Portable Hard Disk Drive, USB 3.0 with\xa0 Automatic Backup, 256 Bit AES Hardware Encrypti...']

# %% [markdown]
# ### From the above code we can see the 10 most popular products by ratings:
#
# * 'SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-400G-GN6MA) with Adapter'
# * 'Redmi 164 cm (65 inches) 4K Ultra HD Android Smart LED TV X65 | L65M6-RA (Black)'
# * 'Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery'
# * 'Redmi 139 cm (55 inches) 4K Ultra HD Android Smart LED TV X55 | L55M6-RA (Black)'
# * 'OnePlus Nord CE 2 Lite 5G (Blue Tide, 8GB RAM, 128GB Storage)'
# * 'Apple iPhone 12 (128GB) - Green'
# *  'Fitbit FB507RGPK Versa 2 Health & Fitness Smartwatch with Heart Rate, Music, Alexa Built-in, Sleep & Swim Tracking, Petal/...'
# * 'Samsung Galaxy M12 (Black,6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime'
# * 'TOZO T6 True Wireless Earbuds Bluetooth Headphones Touch Control with Wireless Charging Case IPX8 Waterproof Stereo Earpho...'
# * 'MI 138.8 cm (55 inches) 5X Series 4K Ultra HD LED Smart Android TV L55M6-ES (Grey)'

# %%
# What are the most popular products per rating? (for all ratings)
pd.set_option("display.max.rows", None) # make sure pandas does not hide any rows
pop_prod_rating = df_dropped_5.loc[df_dropped_5.groupby('Ratings')['No. Of Ratings'].idxmax()] \
                        [['Ratings', 'Name', 'No. Of Ratings', 'Total sales']].sort_values('Ratings', ascending=False)
pop_prod_rating
# Out:
#         Ratings                                               Name  \
# 502813      5.0  FIGMENT Dancing Cactus Talking Toy, Cactus Plu...
# 127564      4.9  Pampers Swaddlers Disposable Baby Diapers, New...
# 244416      4.8  Bounty Personal Air Cooler with Anti Bacterial...
# 96242       4.7                    Hey Dude Men's Wally Sox Loafer
# 507020      4.6                              Amazon Pay eGift Card
# 18802       4.5  AmazonBasics AA Performance Alkaline Non-Recha...
# 60378       4.4  Amazon Basics High-Speed HDMI Cable - 10 Feet ...
# 60737       4.3  SanDisk 128GB Class 10 microSDXC Memory Card w...
# 13904       4.2  Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB S...
# 11583       4.1  boAt BassHeads 100 in-Ear Wired Headphones wit...
# 12127       4.0  boAt Airdopes 441 Bluetooth Truly Wireless in ...
# 265318      3.9  AmazonBasics Microfiber Sheet Set - (Includes ...
# 11588       3.8  boAt Airdopes 121v2 in-Ear True Wireless Earbu...
# 11970       3.7  JBL Tune 215BT, 16 Hrs Playtime with Quick Cha...
# 416053      3.6  Nano Double Sided Tape, EZlifego Traceless Was...
# 11608       3.5  pTron Bassbuds Duo in Ear Earbuds with 32Hrs T...
# 15351       3.4  Skullcandy Dime True Wireless in-Ear Bluetooth...
# 11673       3.3  Tygot Adjustable Aluminium Alloy Tripod Stand ...
# 234789      3.2  Skullcandy Indy Evo Truly Wireless Bluetooth i...
# 266530      3.1  TECHVIDA GLANDOTU Automatic Wireless Portable ...
# 85419       3.0                               Big Fox Men's Loafer
# 28182       2.9                          T-Rock Men's Sports Shoes
# 374694      2.8  NEOSAFE Spark A5005 PVC Labour Safety Shoes (8...
# 24226       2.7  Kuber Industries Wooden Simple Numerical Round...
# 1808        2.6  Prestige Roti Maker PRM 5.0 with Demo CD - Silver
# 13743       2.5  DEVCOMM Phone Bluetooth Stereo System Audio Au...
# 80617       2.4  Car Vacuum Powerful Portable & High Power 12V ...
# 87217       2.3       Bond Street by (Red Tape) Men Brown Moccasin
# 266262      2.2  Shreeji Water Manual Pump Dispenser for 20 Lit...
# 438150      2.1  Sasta Kashmiri walnut without shell in vacuum ...
# 383409      2.0                 Puma Unisex Bosco Jr 2 Dp Sneakers
# 92034       1.9  Bond Street by (Red Tape) Men's Tan Loafers-8 ...
# 438069      1.8  Dried Treats Premium Almonds (Kagzi Almonds, 2...
# 5532        1.7  FnX® Mini Iron Portable Travel Iron Support Dr...
# 1376        1.6  Suzec Mini Heat Sealing Machine for Home Use, ...
# 85665       1.5                         Puma Men's Polo Boat Shoes
# 11361       1.4  Mr Fix® 3D Car Door Invisible Handle Cup Scrat...
# 236106      1.3  GoSale Bluetooth Neckband for OnePlus Earphone...
# 379866      1.2  Kuber Industries Rubber Bathroom Slipper For M...
# 268520      1.1  Citroda Electric Mosquito Killer Lamp USB Rech...
# 234570      1.0  Celly BUZ1 True Wireless Headset, Bluetooth 5....
#
#         No. Of Ratings   Total sales
# 502813              99  6.920100e+04
# 127564           26160  3.402893e+08
# 244416           80282  3.210477e+08
# 96242            84311  8.351848e+08
# 507020          182473  1.824730e+06
# 18802           336487  3.125964e+08
# 60378           437652  1.658701e+08
# 60737           589547  1.005178e+09
# 13904           221269  3.318814e+09
# 11583           375110  1.496689e+08
# 12127           148271  1.926040e+08
# 265318          190982  1.965205e+08
# 11588           188031  2.066461e+08
# 11970            84439  1.265741e+08
# 416053           81051  1.945224e+07
# 11608           166395  1.329496e+08
# 15351            41533  1.037910e+08
# 11673            53252  1.751991e+07
# 234789           35122  2.206364e+08
# 266530           37772  1.469331e+07
# 85419             2926  1.752674e+06
# 28182             9601  2.861098e+06
# 374694            6942  2.672670e+06
# 24226             1977  6.879960e+05
# 1808              1411  4.055214e+06
# 13743             1225  1.715000e+05
# 80617              282  3.381180e+05
# 87217              183  1.180350e+05
# 266262             128  3.059200e+04
# 438150             208  7.904000e+04
# 383409             150  1.014000e+05
# 92034               56  4.284000e+04
# 438069              80  7.053600e+03
# 5532                43  2.790700e+04
# 1376                58  8.642000e+03
# 85665               73  5.591800e+04
# 11361                9  1.611000e+03
# 236106              11  5.489000e+03
# 379866              23  1.413580e+03
# 268520              10  6.990000e+03
# 234570               9  2.001600e+04

# %%
# Filter out top rated products..
pop_prod_rating[(pop_prod_rating['Ratings']>=3.1) & (pop_prod_rating['Ratings']<=4.9)]
# Out:
#         Ratings                                               Name  \
# 127564      4.9  Pampers Swaddlers Disposable Baby Diapers, New...
# 244416      4.8  Bounty Personal Air Cooler with Anti Bacterial...
# 96242       4.7                    Hey Dude Men's Wally Sox Loafer
# 507020      4.6                              Amazon Pay eGift Card
# 18802       4.5  AmazonBasics AA Performance Alkaline Non-Recha...
# 60378       4.4  Amazon Basics High-Speed HDMI Cable - 10 Feet ...
# 60737       4.3  SanDisk 128GB Class 10 microSDXC Memory Card w...
# 13904       4.2  Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB S...
# 11583       4.1  boAt BassHeads 100 in-Ear Wired Headphones wit...
# 12127       4.0  boAt Airdopes 441 Bluetooth Truly Wireless in ...
# 265318      3.9  AmazonBasics Microfiber Sheet Set - (Includes ...
# 11588       3.8  boAt Airdopes 121v2 in-Ear True Wireless Earbu...
# 11970       3.7  JBL Tune 215BT, 16 Hrs Playtime with Quick Cha...
# 416053      3.6  Nano Double Sided Tape, EZlifego Traceless Was...
# 11608       3.5  pTron Bassbuds Duo in Ear Earbuds with 32Hrs T...
# 15351       3.4  Skullcandy Dime True Wireless in-Ear Bluetooth...
# 11673       3.3  Tygot Adjustable Aluminium Alloy Tripod Stand ...
# 234789      3.2  Skullcandy Indy Evo Truly Wireless Bluetooth i...
# 266530      3.1  TECHVIDA GLANDOTU Automatic Wireless Portable ...
#
#         No. Of Ratings   Total sales
# 127564           26160  3.402893e+08
# 244416           80282  3.210477e+08
# 96242            84311  8.351848e+08
# 507020          182473  1.824730e+06
# 18802           336487  3.125964e+08
# 60378           437652  1.658701e+08
# 60737           589547  1.005178e+09
# 13904           221269  3.318814e+09
# 11583           375110  1.496689e+08
# 12127           148271  1.926040e+08
# 265318          190982  1.965205e+08
# 11588           188031  2.066461e+08
# 11970            84439  1.265741e+08
# 416053           81051  1.945224e+07
# 11608           166395  1.329496e+08
# 15351            41533  1.037910e+08
# 11673            53252  1.751991e+07
# 234789           35122  2.206364e+08
# 266530           37772  1.469331e+07

# %%
# List out these top rated products that were filtered out
list(pop_prod_rating[(pop_prod_rating['Ratings']>=3.1) & (pop_prod_rating['Ratings']<=4.9)]['Name'])
# Out:
# ['Pampers Swaddlers Disposable Baby Diapers, Newborn/Size (< 10 lb), 140 Count, Enormous Pack, Packaging May Vary',
#  'Bounty Personal Air Cooler with Anti Bacterial Honeycomb Pads, 3rd Turbo Fan, Powerful Air Throw with Auto Swing and 3-Spe...',
#  "Hey Dude Men's Wally Sox Loafer",
#  'Amazon Pay eGift Card',
#  'AmazonBasics AA Performance Alkaline Non-Rechargeable Batteries (48 Count) - Appearance May Vary',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (Latest Standard) - Supports Ethernet, 3D, 4K video,Black',
#  'SanDisk 128GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-128G-GN6MA)',
#  'Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen Rep...',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)',
#  'boAt Airdopes 441 Bluetooth Truly Wireless in Ear Earbuds with Mic with Up to 35H Total Playback Iwp Technology Immersive ...',
#  'AmazonBasics Microfiber Sheet Set - (Includes 1 bedsheet, 1 Fitted Sheet with Elastic, 2 Pillow Covers) King, Yellow Scallop',
#  'boAt Airdopes 121v2 in-Ear True Wireless Earbuds with Upto 14 Hours Playback, 8MM Drivers, Battery Indicators, Lightweight...',
#  'JBL Tune 215BT, 16 Hrs Playtime with Quick Charge, in Ear Bluetooth Wireless Earphones with Mic, 12.5mm Premium Earbuds wi...',
#  'Nano Double Sided Tape, EZlifego Traceless Washable Adhesive Tape Removable, Heavy Duty Double Sided Sticky Tape Strong Cl...',
#  'pTron Bassbuds Duo in Ear Earbuds with 32Hrs Total Playtime, Bluetooth 5.1 Wireless, Stereo Audio, Touch Control TWS, with...',
#  'Skullcandy Dime True Wireless in-Ear Bluetooth Earbuds Compatible with iPhone and Android/Charging Case and Microphone/Gre...',
#  'Tygot Adjustable Aluminium Alloy Tripod Stand Holder for Mobile Phones & Camera, 360 mm -1060 mm (42 Inch), 1/4 inch Screw...',
#  'Skullcandy Indy Evo Truly Wireless Bluetooth in Ear Earbuds with Mic (Blue)',
#  'TECHVIDA GLANDOTU Automatic Wireless Portable Mini Rechargeable Water Bottle Can Dispenser Pump Upto 20 Litre Bottle with ...']

# %% [markdown]
# ### From the above code we can see the most popular products per ratings from 3.1 to 4.9:
#
# * 'Pampers Swaddlers Disposable Baby Diapers, Newborn/Size (< 10 lb), 140 Count, Enormous Pack, Packaging May Vary',
# * 'Bounty Personal Air Cooler with Anti Bacterial Honeycomb Pads, 3rd Turbo Fan, Powerful Air Throw with Auto Swing and 3-Spe...',
# * "Hey Dude Men's Wally Sox Loafer",
# * 'Amazon Pay eGift Card',
# * 'AmazonBasics AA Performance Alkaline Non-Rechargeable Batteries (48 Count) - Appearance May Vary',
# * 'Amazon Basics High-Speed HDMI Cable - 10 Feet (Latest Standard) - Supports Ethernet, 3D, 4K video,Black',
# * 'SanDisk 128GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-128G-GN6MA)',
# * 'Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen Rep...',
# * 'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)',
# * 'boAt Airdopes 441 Bluetooth Truly Wireless in Ear Earbuds with Mic with Up to 35H Total Playback Iwp Technology Immersive ...',
# * 'AmazonBasics Microfiber Sheet Set - (Includes 1 bedsheet, 1 Fitted Sheet with Elastic, 2 Pillow Covers) King, Yellow Scallop',
# * 'boAt Airdopes 121v2 in-Ear True Wireless Earbuds with Upto 14 Hours Playback, 8MM Drivers, Battery Indicators, Lightweight...',
# * 'JBL Tune 215BT, 16 Hrs Playtime with Quick Charge, in Ear Bluetooth Wireless Earphones with Mic, 12.5mm Premium Earbuds wi...',
# * 'Nano Double Sided Tape, EZlifego Traceless Washable Adhesive Tape Removable, Heavy Duty Double Sided Sticky Tape Strong Cl...',
# * 'pTron Bassbuds Duo in Ear Earbuds with 32Hrs Total Playtime, Bluetooth 5.1 Wireless, Stereo Audio, Touch Control TWS, with...',
# * 'Skullcandy Dime True Wireless in-Ear Bluetooth Earbuds Compatible with iPhone and Android/Charging Case and Microphone/Gre...',
# * 'Tygot Adjustable Aluminium Alloy Tripod Stand Holder for Mobile Phones & Camera, 360 mm -1060 mm (42 Inch), 1/4 inch Screw...',
# * 'Skullcandy Indy Evo Truly Wireless Bluetooth in Ear Earbuds with Mic (Blue)',
# * 'TECHVIDA GLANDOTU Automatic Wireless Portable Mini Rechargeable Water Bottle Can Dispenser Pump Upto 20 Litre Bottle with ...'

# %%
# What is the total sales and number of sales of products per rating?
# The number of ratings give an idea of the number of sales.
total_sales_ratings = df_dropped_5.groupby('Ratings', as_index=False)['No. Of Ratings', 'Total sales'].sum() \
                            .sort_values(['Ratings', 'Total sales'], ascending=False)
total_sales_ratings
# Out:
#     Ratings  No. Of Ratings   Total sales
# 40      5.0           56355  1.200519e+08
# 39      4.9           66228  5.629130e+08
# 38      4.8         1054777  5.864115e+09
# 37      4.7         2592571  2.348309e+10
# 36      4.6         6669347  3.268816e+10
# 35      4.5        21375391  7.546737e+10
# 34      4.4        35717810  7.816579e+10
# 33      4.3        39475459  1.259095e+11
# 32      4.2        39558757  1.319741e+11
# 31      4.1        49442397  9.682539e+10
# 30      4.0        23112603  3.944909e+10
# 29      3.9        22768853  3.339670e+10
# 28      3.8        17249033  2.355845e+10
# 27      3.7         9551995  1.073098e+10
# 26      3.6         6297226  5.557731e+09
# 25      3.5         5246494  5.090270e+09
# 24      3.4         2395808  3.166459e+09
# 23      3.3         1363887  1.080078e+09
# 22      3.2          990849  1.994229e+09
# 21      3.1          450916  5.490178e+08
# 20      3.0          211519  1.948724e+08
# 19      2.9          149081  1.105535e+08
# 18      2.8           73919  6.582079e+07
# 17      2.7           45624  4.282118e+07
# 16      2.6           28039  3.520783e+07
# 15      2.5           17485  1.737756e+07
# 14      2.4           10493  1.151943e+07
# 13      2.3            8582  1.109023e+07
# 12      2.2            5155  4.805342e+06
# 11      2.1            3493  4.977939e+06
# 10      2.0            6324  7.794467e+06
# 9       1.9            1729  2.195811e+06
# 8       1.8            1542  1.733414e+06
# 7       1.7            1037  1.267670e+06
# 6       1.6             833  8.280068e+05
# 5       1.5            1307  1.376513e+06
# 4       1.4             616  5.008256e+05
# 3       1.3             363  3.026018e+05
# 2       1.2             164  3.734000e+05
# 1       1.1              10  6.990000e+03
# 0       1.0            8957  1.482493e+07

# %%
# What are the most popular products by DISCOUNT pricing strategy?
pd.set_option("display.max.rows", 10) # reduce number of records shown to default
pop_product_strategy = df_dropped_5.sort_values(['No. Of Ratings', 'Percentage Discount'], ascending=False).head(100)
pop_product_strategy
# Out:
#                                                      Name  \
# 62513   SanDisk 256GB Class 10 MicroSD Card with Adapt...
# 73153   SanDisk 256GB Class 10 MicroSD Card with Adapt...
# 60737   SanDisk 128GB Class 10 microSDXC Memory Card w...
# 70497   SanDisk 128GB Class 10 microSDXC Memory Card w...
# 68452   SanDisk 512GB Ultra MicroSDXC UHS-I Memory Car...
# ...                                                   ...
# 32366   Huggies Complete Comfort Wonder Pants, Medium ...
# 32427   Huggies Complete Comfort Wonder Pants, Medium ...
# 127372  Huggies Wonder Pants, Medium (M) Size Baby Dia...
# 127196  Huggies Wonder Pants Diapers, Extra Small (24 ...
# 33199   Huggies Wonder Pants Small (S) Size Baby Diape...
#
#                Main Category        Sub-category  Ratings  No. Of Ratings  \
# 62513    tv, audio & cameras  Camera Accessories      4.3          589547
# 73153    tv, audio & cameras             Cameras      4.3          589547
# 60737    tv, audio & cameras  Camera Accessories      4.3          589547
# 70497    tv, audio & cameras             Cameras      4.3          589547
# 68452    tv, audio & cameras  Camera Accessories      4.3          589547
# ...                      ...                 ...      ...             ...
# 32366   toys & baby products       Baby Products      4.2          215914
# 32427   toys & baby products       Baby Products      4.2          215914
# 127372  toys & baby products             Diapers      4.2          215914
# 127196  toys & baby products             Diapers      4.2          215914
# 33199   toys & baby products       Baby Products      4.2          215914
#
#         Discount Price  Actual Price   Total sales  Percentage Discount
# 62513           3324.0        7999.0  1.959654e+09            58.444806
# 73153           3324.0        7999.0  1.959654e+09            58.444806
# 60737           1705.0        3999.0  1.005178e+09            57.364341
# 70497           1705.0        3999.0  1.005178e+09            57.364341
# 68452           8022.0       15000.0  4.729346e+09            46.520000
# ...                ...           ...           ...                  ...
# 32366           1022.0        1398.0  2.206641e+08            26.895565
# 32427            567.0         699.0  1.224232e+08            18.884120
# 127372           981.0        1198.0  2.118116e+08            18.113523
# 127196           340.0         398.0  7.341076e+07            14.572864
# 33199            199.0         225.0  4.296689e+07            11.555556
#
# [100 rows x 9 columns]

# %%
# let's list out the popular products by discount strategy
list(pop_product_strategy['Name'])
# Out:
# ['SanDisk 256GB Class 10 MicroSD Card with Adapter (SDSQUAR-256G-GN6MA)',
#  'SanDisk 256GB Class 10 MicroSD Card with Adapter (SDSQUAR-256G-GN6MA)',
#  'SanDisk 128GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-128G-GN6MA)',
#  'SanDisk 128GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-128G-GN6MA)',
#  'SanDisk 512GB Ultra MicroSDXC UHS-I Memory Card - 100MB/s, C10, U1, Full HD, A1, Micro SD Card - SDSQUAR-512G-GN6MN',
#  'SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-400G-GN6MA) with Adapter',
#  'SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-400G-GN6MA) with Adapter',
#  'SanDisk UHS-I A1 98Mbps 32GB Ultra MicroSD Memory Card',
#  'SanDisk UHS-I A1 98Mbps 32GB Ultra MicroSD Memory Card',
#  'SanDisk Ultra 64GB UHS-I Class 10 Micro SD Memory Card (SDSQUNC-064G-GN3MN)',
#  'SanDisk Ultra 64GB UHS-I Class 10 Micro SD Memory Card (SDSQUNC-064G-GN3MN)',
#  'SanDisk 16GB Ultra MicroSDHC Memory Card (SDSQUAR-016G-GN6MN)',
#  'SanDisk 16GB Ultra MicroSDHC Memory Card (SDSQUAR-016G-GN6MN)',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (2-Pack) -Latest Standard for Xbox, PlayStation, Television, Personal Comput...',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (2-Pack) -Latest Standard for Xbox, PlayStation, Television, Personal Comput...',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (Latest Standard) - Supports Ethernet, 3D, 4K video,Black',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (Latest Standard) - Supports Ethernet, 3D, 4K video,Black',
#  'Amazon Basics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot',
#  'Amazon Basics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot',
#  'Amazon Basics High-Speed HDMI Cable, 3 Feet (Black, 2-Pack) - Supports Ethernet, 3D, 4K video',
#  'Amazon Basics High-Speed HDMI Cable, 3 Feet (Black, 2-Pack) - Supports Ethernet, 3D, 4K video',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (2-Pack) -Latest Standard for Xbox, PlayStation, Television, Personal Comput...',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (Latest Standard) - Supports Ethernet, 3D, 4K video,Black',
#  'Amazon Basics High-Speed HDMI Cable - 10 Feet (Latest Standard) - Supports Ethernet, 3D, 4K video,Black',
#  'Amazon Basics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot',
#  'Amazon Basics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot',
#  'Amazon Basics High-Speed HDMI Cable, 3 Feet (Black, 2-Pack) - Supports Ethernet, 3D, 4K video',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black',
#  'Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black',
#  'boAt BassHeads 100 Delhi Capitals Edition Wired in Ear Earphones with Super Extra Bass, with mic, Hawk Inspired Design and...',
#  'boAt BassHeads 100 Delhi Capitals Edition Wired in Ear Earphones with Super Extra Bass, with mic, Hawk Inspired Design and...',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)',
#  'boAt Bassheads 100 in Ear Wired Earphones with Mic(Furious Red)',
#  'boAt Bassheads 100 Wired in Ear Earphones with Mic (Mint Green)',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (White)',
#  'boAt Bassheads 100 Wired in Ear Earphones with Mic (Mint Orange)',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)',
#  'boAt Bassheads 100 in Ear Wired Earphones with Mic(Furious Red)',
#  'boAt Bassheads 100 Wired in Ear Earphones with Mic (Mint Green)',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (White)',
#  'boAt Bassheads 100 Wired in Ear Earphones with Mic (Mint Orange)',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black) & Bassheads 242 in Ear Wired Earphones with Mic(Active Black)...',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black) & Bassheads 242 in Ear Wired Earphones with Mic(Active Black)',
#  'AmazonBasics AAA Performance Alkaline Non-rechargeable Batteries (36 Count) - Appearance May Vary',
#  'AmazonBasics AA Performance Alkaline Non-Rechargeable Batteries (48 Count) - Appearance May Vary',
#  'AmazonBasics AA Performance Alkaline Non-Rechargeable Batteries (48 Count) - Appearance May Vary',
#  'Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9A Sport (Carbon Black, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'SanDisk 64GB Extreme microSDXC, U3, C10, V30, UHS 1, 160MB/s R, 60MB/s W, A2 Card, for 4K Video Rec on Smartphones, Action...',
#  'SanDisk 64GB Extreme microSDXC, U3, C10, V30, UHS 1, 160MB/s R, 60MB/s W, A2 Card, for 4K Video Rec on Smartphones, Action...',
#  'boAt Bassheads 220 Wired in Ear Earphones(Black Indi)',
#  'boAt BassHeads 220 Wired in Ear Earphones with Inline Mic(Black)',
#  'boAt Bassheads 220 Wired in Ear Earphones(Indi Lime)',
#  'boAt Bassheads 220 Wired in Ear Earphones(Indi Blue)',
#  'boAt Bassheads 220 Wired in Ear Earphones with Mic(Raging Red)',
#  'boAt Bassheads 220 Wired in Ear Earphones(Raging Red Indi)',
#  'boAt Bassheads 220 in Ear Wired Earphones(Fiery Orange Indi)',
#  'boAt Bassheads 220 Wired in Ear Earphones(Black Indi)',
#  'boAt Bassheads 220 Wired in Ear Earphones(Indi Lime)',
#  'boAt Bassheads 220 Wired in Ear Earphones(Indi Blue)',
#  'boAt Bassheads 220 Wired in Ear Earphones with Mic(Raging Red)',
#  'boAt Bassheads 220 Wired in Ear Earphones(Raging Red Indi)',
#  'boAt Bassheads 220 in Ear Wired Earphones(Fiery Orange Indi)',
#  'boAt Bassheads 220 Wired Earphones with Inline Mic(Frosty White)',
#  'boAt Bassheads 220 Wired in Ear Earphones with Inline Mic(Blue)',
#  'boAt Bassheads 220 Wired in Ear Earphones with Inline Mic(Blue)',
#  'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Neon Lime)',
#  'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Neon Lime)',
#  'boAt BassHeads 225 Special Edition in-Ear Wired Headphones with Mic (Blue)',
#  'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Forest Green)',
#  'boAt Bassheads 225 in Ear Wired Earphones with Mic(Red)',
#  'boAt Bassheads 225 in Ear Wired Earphones with Mic(Red)',
#  'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Frosty White)',
#  'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Forest Green)',
#  'boAt Bassheads 225 in Ear Wired Earphones with Mic(Red)',
#  'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Frosty White)',
#  'boAt Bassheads 225 in Ear Wired Earphones with Mic(Molten Orange)',
#  'Pigeon Polypropylene Mini Handy and Compact Chopper with 3 Blades for Effortlessly Chopping Vegetables and Fruits for Your...',
#  'Redmi Note 10S (Cosmic Purple, 6GB RAM, 128GB Storage)\xa0 - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen R...',
#  'Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen Rep...',
#  'Huggies Complete Comfort Wonder Pants,Large (L) Size Baby Diaper Pants,(64 count) (9-14Kg) with 5 in 1 Comfort',
#  'Huggies Complete Comfort Wonder Pants Extra Large (XL) Size Baby Diaper Pants Sumo Pack, 168 count, with 5 in 1 Comfort',
#  'Huggies Complete Comfort Wonder Pants, Small (S) Size Baby Diaper Pants, Combo Pack of 2, 56 count Per Pack, (112 count) w...',
#  'Huggies Complete Comfort Wonder Pants Large (L) Size Baby Diaper Pants Sumo Pack, 192 count, with 5 in 1 Comfort',
#  'Huggies Wonder Pants, Monthly Box Pack Diapers, Large , 128 Count & Huggies New Dry, Taped Diapers, Large , 52 Counts',
#  'Huggies Wonder Pants, Monthly Box Pack Diapers, Extra Large (XL) , 112 Count & Diapers Sumo Pack, Extra Large (168 Count)',
#  'Huggies Complete Comfort Wonder Pants, Medium (7-12kg) Size Count 100 Baby Diaper Pants Combo Pack of 2, 50 count Per Pac...',
#  'Huggies Complete Comfort Wonder Pants, Medium (M) Size Baby Diaper Pants, 50 count, with 5 in 1 Comfort',
#  'Huggies Wonder Pants, Medium (M) Size Baby Diaper Pants, 7 - 12 kg, 50 count & Wonder Pants Medium (M) Size Baby Diaper Pa...',
#  'Huggies Wonder Pants Diapers, Extra Small (24 Count) & Huggies Cucumber and Aloe Vera Baby Wipes (72 Count)',
#  'Huggies Wonder Pants Small (S) Size Baby Diaper Pants, 20 count, with Bubble Bed Technology for comfort']

# %% [markdown]
# ### From the above code we can see that the 10 most popular product by discount pricing strategy are:
#
# * 'SanDisk 256GB Class 10 MicroSD Card with Adapter (SDSQUAR-256G-GN6MA)'
# * 'SanDisk 512GB Ultra MicroSDXC UHS-I Memory Card - 100MB/s, C10, U1, Full HD, A1, Micro SD Card - SDSQUAR-512G-GN6MN'
# * 'Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black'
# * 'Amazon Basics High-Speed HDMI Cable - 10 Feet (2-Pack) -Latest Standard for Xbox, PlayStation, Television, Personal Comput...'
# * 'boAt BassHeads 100 Delhi Capitals Edition Wired in Ear Earphones with Super Extra Bass, with mic'
# * 'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)'
# * 'AmazonBasics AAA Performance Alkaline Non-rechargeable Batteries (36 Count) - Appearance May Vary'
# * 'Pigeon Polypropylene Mini Handy and Compact Chopper with 3 Blades for Effortlessly Chopping Vegetables and Fruits for Your'
# * 'Huggies Complete Comfort Wonder Pants Large (L) Size Baby Diaper Pants Sumo Pack, 192 count, with 5 in 1 Comfort'
# * 'Huggies Wonder Pants Small (S) Size Baby Diaper Pants, 20 count, with Bubble Bed Technology for comfort'

# %%
# What are the top selling products? 
df_dropped_5.sort_values(['No. Of Ratings', 'Total sales', 'Ratings'], ascending=False).head(200)
# Out:
#                                                      Name  \
# 66723   SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...
# 79485   SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...
# 68452   SanDisk 512GB Ultra MicroSDXC UHS-I Memory Car...
# 62513   SanDisk 256GB Class 10 MicroSD Card with Adapt...
# 73153   SanDisk 256GB Class 10 MicroSD Card with Adapt...
# ...                                                   ...
# 233093  boAt Airdopes 141 Pro True Wireless in Ear Ear...
# 233085  boAt Airdopes 141 Bluetooth Truly Wireless in ...
# 233087  boAt Airdopes 141 Bluetooth Truly Wireless in ...
# 233096  boAt Airdopes 141 Bluetooth Truly Wireless in ...
# 15226   AmazonBasics 9 Volt Everyday Alkaline Batterie...
#
#               Main Category        Sub-category  Ratings  No. Of Ratings  \
# 66723   tv, audio & cameras  Camera Accessories      4.3          589547
# 79485   tv, audio & cameras             Cameras      4.3          589547
# 68452   tv, audio & cameras  Camera Accessories      4.3          589547
# 62513   tv, audio & cameras  Camera Accessories      4.3          589547
# 73153   tv, audio & cameras             Cameras      4.3          589547
# ...                     ...                 ...      ...             ...
# 233093  tv, audio & cameras          Headphones      3.9          172343
# 233085  tv, audio & cameras          Headphones      3.9          172343
# 233087  tv, audio & cameras          Headphones      3.9          172343
# 233096  tv, audio & cameras          Headphones      3.9          172343
# 15226   tv, audio & cameras     All Electronics      4.3          170793
#
#         Discount Price  Actual Price   Total sales  Percentage Discount
# 66723          15600.0       22289.0  9.196933e+09            30.010319
# 79485          15600.0       22289.0  9.196933e+09            30.010319
# 68452           8022.0       15000.0  4.729346e+09            46.520000
# 62513           3324.0        7999.0  1.959654e+09            58.444806
# 73153           3324.0        7999.0  1.959654e+09            58.444806
# ...                ...           ...           ...                  ...
# 233093          1399.0        2990.0  2.411079e+08            53.210702
# 233085          1299.0        3995.0  2.238736e+08            67.484355
# 233087          1299.0        4490.0  2.238736e+08            71.069042
# 233096          1299.0        4490.0  2.238736e+08            71.069042
# 15226            429.0         600.0  7.327020e+07            28.500000
#
# [200 rows x 9 columns]

# %%
# List the top selling products? 
df_dropped_5.sort_values(['No. Of Ratings', 'Total sales', 'Ratings'], ascending=False).head(200).Name.unique()
# Out:
# array(['SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-400G-GN6MA) with Adapter',
#        'SanDisk 512GB Ultra MicroSDXC UHS-I Memory Card - 100MB/s, C10, U1, Full HD, A1, Micro SD Card - SDSQUAR-512G-GN6MN',
#        'SanDisk 256GB Class 10 MicroSD Card with Adapter (SDSQUAR-256G-GN6MA)',
#        'SanDisk 128GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-128G-GN6MA)',
#        'SanDisk Ultra 64GB UHS-I Class 10 Micro SD Memory Card (SDSQUNC-064G-GN3MN)',
#        'SanDisk UHS-I A1 98Mbps 32GB Ultra MicroSD Memory Card',
#        'SanDisk 16GB Ultra MicroSDHC Memory Card (SDSQUAR-016G-GN6MN)',
#        'Amazon Basics High-Speed HDMI Cable - 10 Feet (2-Pack) -Latest Standard for Xbox, PlayStation, Television, Personal Comput...',
#        'Amazon Basics High-Speed HDMI Cable, 3 Feet (Black, 2-Pack) - Supports Ethernet, 3D, 4K video',
#        'Amazon Basics High-Speed HDMI Cable - 10 Feet (Latest Standard) - Supports Ethernet, 3D, 4K video,Black',
#        'Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black',
#        'Amazon Basics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot',
#        'Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black',
#        'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black) & Bassheads 242 in Ear Wired Earphones with Mic(Active Black)...',
#        'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black) & Bassheads 242 in Ear Wired Earphones with Mic(Active Black)',
#        'boAt BassHeads 100 Delhi Capitals Edition Wired in Ear Earphones with Super Extra Bass, with mic, Hawk Inspired Design and...',
#        'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)',
#        'boAt Bassheads 100 in Ear Wired Earphones with Mic(Furious Red)',
#        'boAt Bassheads 100 Wired in Ear Earphones with Mic (Mint Green)',
#        'boAt BassHeads 100 in-Ear Wired Headphones with Mic (White)',
#        'boAt Bassheads 100 Wired in Ear Earphones with Mic (Mint Orange)',
#        'AmazonBasics AAA Performance Alkaline Non-rechargeable Batteries (36 Count) - Appearance May Vary',
#        'AmazonBasics AA Performance Alkaline Non-Rechargeable Batteries (48 Count) - Appearance May Vary',
#        'Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor',
#        'Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#        'Redmi 9A Sport (Carbon Black, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#        'Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#        'Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#        'SanDisk 64GB Extreme microSDXC, U3, C10, V30, UHS 1, 160MB/s R, 60MB/s W, A2 Card, for 4K Video Rec on Smartphones, Action...',
#        'boAt BassHeads 225 Special Edition in-Ear Wired Headphones with Mic (Blue)',
#        'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Forest Green)',
#        'boAt Bassheads 225 in Ear Wired Earphones with Mic(Red)',
#        'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Frosty White)',
#        'boAt Bassheads 225 in Ear Wired Earphones with Mic(Molten Orange)',
#        'boAt Bass Heads 225 in-Ear Wired Headphones with Mic (Neon Lime)',
#        'boAt Bassheads 220 Wired in Ear Earphones with Inline Mic(Blue)',
#        'boAt Bassheads 220 Wired in Ear Earphones(Black Indi)',
#        'boAt BassHeads 220 Wired in Ear Earphones with Inline Mic(Black)',
#        'boAt Bassheads 220 Wired in Ear Earphones(Indi Lime)',
#        'boAt Bassheads 220 Wired in Ear Earphones(Indi Blue)',
#        'boAt Bassheads 220 Wired in Ear Earphones with Mic(Raging Red)',
#        'boAt Bassheads 220 Wired in Ear Earphones(Raging Red Indi)',
#        'boAt Bassheads 220 in Ear Wired Earphones(Fiery Orange Indi)',
#        'boAt Bassheads 220 Wired Earphones with Inline Mic(Frosty White)',
#        'Pigeon Polypropylene Mini Handy and Compact Chopper with 3 Blades for Effortlessly Chopping Vegetables and Fruits for Your...',
#        'Redmi Note 10S (Cosmic Purple, 6GB RAM, 128GB Storage)\xa0 - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen R...',
#        'Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen Rep...',
#        'Huggies Wonder Pants, Monthly Box Pack Diapers, Extra Large (XL) , 112 Count & Diapers Sumo Pack, Extra Large (168 Count)',
#        'Huggies Complete Comfort Wonder Pants Extra Large (XL) Size Baby Diaper Pants Sumo Pack, 168 count, with 5 in 1 Comfort',
#        'Huggies Wonder Pants, Monthly Box Pack Diapers, Large , 128 Count & Huggies New Dry, Taped Diapers, Large , 52 Counts',
#        'Huggies Complete Comfort Wonder Pants Large (L) Size Baby Diaper Pants Sumo Pack, 192 count, with 5 in 1 Comfort',
#        'Huggies Complete Comfort Wonder Pants, Medium (7-12kg) Size Count 100 Baby Diaper Pants Combo Pack of 2, 50 count Per Pac...',
#        'Huggies Wonder Pants, Medium (M) Size Baby Diaper Pants, 7 - 12 kg, 50 count & Wonder Pants Medium (M) Size Baby Diaper Pa...',
#        'Huggies Complete Comfort Wonder Pants, Small (S) Size Baby Diaper Pants, Combo Pack of 2, 56 count Per Pack, (112 count) w...',
#        'Huggies Complete Comfort Wonder Pants,Large (L) Size Baby Diaper Pants,(64 count) (9-14Kg) with 5 in 1 Comfort',
#        'Huggies Complete Comfort Wonder Pants, Medium (M) Size Baby Diaper Pants, 50 count, with 5 in 1 Comfort',
#        'Huggies Wonder Pants Diapers, Extra Small (24 Count) & Huggies Cucumber and Aloe Vera Baby Wipes (72 Count)',
#        'Huggies Wonder Pants Small (S) Size Baby Diaper Pants, 20 count, with Bubble Bed Technology for comfort',
#        'Huggies Complete Comfort Wonder Pants, Double Extra Large (15-25kg) Size,(48 count) Baby Diaper Pants, Combo Pack of 2, 24...',
#        'Huggies Complete Comfort Wonder Pants Extra Large (12-17kg) Size, 56 count Baby Diaper Pants, with 5 in 1 Comfort',
#        'Huggies Complete Comfort Wonder Pants, Extra Small (XS),48 Count, Upto 5 kg Size Baby Diaper Pants, Combo Pack of 2, 24 co...',
#        'SanDisk Extreme Pro SD UHS I 1TB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#        'SanDisk Extreme Pro SD UHS I 512GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#        'SanDisk Extreme Pro SD UHS I 256GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 140MB/s Write',
#        'SanDisk Extreme SDXC, SDXVF 256GB, V30, U3, C10, UHS-I, 90MB/s R, 60MB/s W, for 4K Video',
#        'SanDisk Extreme SD UHS I 256GB Card for 4K Video for DSLR and Mirrorless Cameras 180MB/s Read & 130MB/s Write',
#        'SanDisk Extreme SDXC, SDXVF 128GB, V30, U3, C10, UHS-I, 90MB/s R, 60MB/s W, for 4K Video',
#        'SanDisk Extreme Pro SD UHS I 128GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 90MB/s Write',
#        'SanDisk Extreme SD UHS I 128GB Card for 4K Video for DSLR and Mirrorless Cameras 180MB/s Read & 90MB/s Write',
#        'SanDisk Extreme Pro SDHC, SDXXG 32GB, U3, C10, V30, UHS-I,4K, 95MB/s R, 90MB/s W',
#        'SanDisk Extreme Pro SD UHS I 64GB Card for 4K Video for DSLR and Mirrorless Cameras 200MB/s Read & 90MB/s Write',
#        'SanDisk 32GB Extreme SDHC, SDXVE, V30, U3, C10, UHS-I, 90MB/s R, 40MB/s W, for 4K Video',
#        'SanDisk Extreme SD UHS I 64GB Card for 4K Video for DSLR and Mirrorless Cameras 170MB/s Read & 80MB/s Write',
#        'SanDisk Extreme Pro SD UHS I 32GB Card for 4K Video for DSLR and Mirrorless Cameras 100MB/s Read & 90MB/s Write',
#        'SanDisk Extreme SD UHS I 32GB Card for 4K Video for DSLR and Mirrorless Cameras 100MB/s Read & 60MB/s Write',
#        'TOZO T6 True Wireless Earbuds Bluetooth Headphones Touch Control with Wireless Charging Case IPX8 Waterproof Stereo Earpho...',
#        'JBL C100SI Wired in Ear Headphones with Mic, Pure Bass Sound (Black) & C50HI, Wired in Ear Headphones with Mic (Blue) & C5...',
#        'JBL C100SI Wired in Ear Headphones with Mic, Pure Bass Sound, One Button Multi-Function Remote, Angled Buds for Comfort fi...',
#        'JBL C100SI Wired in Ear Headphones with Mic, Pure Bass Sound, One Button Multi-Function Remote (Black) & C50HI, Wired in E...',
#        'JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Angled Buds for Comfor...',
#        'JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Premium Metallic Finis...',
#        'SanDisk Ultra USB 3.0 256 GB Pen Drive (SDDD3-256G-I35, Black, Silver)',
#        'SanDisk Ultra Dual SDDD3-128G-I35 USB 3.0 128GB Flash Drive (Dual Micro-USB and USB 3.0 connectors)',
#        'SanDisk Ultra Dual 64GB USB 3.0 OTG Pen Drive (Gold)',
#        'SanDisk Ultra Dual 64 GB USB 3.0 OTG Pen Drive (Black)',
#        'SanDisk Ultra Dual 32 GB USB 3.0 OTG Pen Drive (Black)',
#        'SanDisk SDDD3-032G-I35GW Ultra Dual 32GB USB 3.0 OTG Pen Drive (Gold)',
#        'AmazonBasics Microfiber Sheet Set - (Includes 1 bedsheet, 1 Fitted Sheet with Elastic, 2 Pillow Covers) King, Yellow Scallop',
#        'boAt Airdopes 121 PRO True Wireless in Ear Earbuds Signature Sound(Royal Blue) & Xtend/Xtend RTL Smartwatch with Alexa Bui...',
#        'boAt Airdopes 121v2 in-Ear True Wireless Earbuds with Upto 14 Hours Playback, 8MM Drivers, Battery Indicators, Lightweight...',
#        'boAt Airdopes 121v2 in-Ear True Wireless Earbuds with Upto 14 Hours Playback & Stone 135 Portable Wireless Speaker with 5W...',
#        'boAt Airdopes 121v2 in-Ear True Wireless Earbuds with Upto 14 Hours Playback & Multifunction Controls (Active Black, with ...',
#        'boAt Airdopes 121v2 in-Ear True Wireless Earbuds with Upto 14 Hours Playback, 8MM Drivers & Multifunction Controls (Active...',
#        'boAt Airdopes 121 PRO True Wireless in Ear Earbuds Signature Sound, Quad Mic ENx, Beast Mode for Gaming, 40H Playtime, IW...',
#        'TP-LINK WiFi Dongle 300 Mbps Mini Wireless Network USB Wi-Fi Adapter for PC Desktop Laptop(Supports Windows 11/10/8.1/8/7/...',
#        'TP-Link AC1300 Nano Wireless MU-MIMO USB 2.0 Adapter, Dual-Band, Miniature Design, Supports Windows 10/8.1/8/7, Mac OS 10....',
#        'TP-Link USB WiFi Dongle 300Mbps High Gain Wireless Network Wi-Fi Adapter for PC Desktop and Laptops. Supports Win10/8.1/8/...',
#        'TP-Link Nano USB WiFi Dongle 150Mbps High Gain Wireless Network Wi-Fi Adapter for PC Desktop and Laptops, Supports Windows...',
#        'TP-LINK TL-WN821N 300 MBPS WiFi WI-FI Wireless N USB Adapter, MIMO, WPS Button, Supports Windows 11/10/8.1/8/7/XP, Mac OS ...',
#        'TP-Link USB WiFi Adapter for PC(TL-WN725N), N150 Wireless Network Adapter for Desktop - Nano Size WiFi Dongle Compatible w...',
#        'Amazon Pay eGift Card',
#        'AmazonBasics AA Performance Alkaline Non-Rechargeable Batteries (20-Pack) - Appearance May Vary',
#        'Amazon Basics USB A to Lightning MFi Certified Charging Cable (White, 1.2 meter)',
#        'Amazon Basics USB A to Lightning MFi Certified Charging Cable (Black, 1.2 meter)',
#        'boAt Airdopes 141 Pro True Wireless in Ear Earbuds with 45H Playtime, Quad Mics Enx Tech, 12mm Drivers, ASAP Charge, Beast...',
#        'boAt Airdopes 141 Bluetooth Truly Wireless in Ear Earbuds with mic, 42H Playtime, Beast Mode(Low Latency Upto 80ms) for Ga...',
#        'boAt Airdopes 141 Bluetooth Truly Wireless in Ear Earbuds with 42H Playtime, Beast Mode(Low Latency Upto 80ms) for Gaming,...',
#        'boAt Airdopes 141 Bluetooth Truly Wireless in Ear Earbuds with 42H Playtime & Rockerz 450 Bluetooth On Ear Headphones with...',
#        'boAt Airdopes 141 True Wireless in Ear Earbuds with mic, 42H Playtime, Beast Mode & Stone 180 5W Bluetooth Speaker with Up...',
#        'boAt Airdopes 141 True Wireless in Ear Earbuds with mic, 42H Playtime & Stone 180 5W Bluetooth Speaker with Upto 10 Hours ...',
#        'boAt Airdopes 141 True Wireless Earbuds with 42H Playtime, Beast™ Mode for Gaming & Stone 135 Portable Wireless Speaker wi...',
#        'AmazonBasics 9 Volt Everyday Alkaline Batteries (4-Pack)'],
#       dtype=object)

# %% [markdown]
# ### Top 20 selling products are:
#
# * The "SanDisk MicroSDXC Memory Card" products
#
# * The "Amazon Basics High-Speed HDMI Cable" products
#
# * The "boAt BassHeads 100 in-Ear Wired Headphones" products
#
# * The "AmazonBasics Performance Alkaline Non-rechargeable Batteries" products
#
# * The "Pigeon Polypropylene Mini Handy and Compact Chopper with 3 Blades" product
#
# * The "Redmi Note 10S" products
#
# * The "Huggies Wonder Pants, Monthly Box Pack Diapers" products
#
# * The "SanDisk Extreme SD UHS I 32GB Card" products
#
# * The "TOZO T6 True Wireless Earbuds Bluetooth Headphones" products
#
# * The "JBL C100SI Wired in Ear Headphones with Mic" products
#
# * The "SanDisk Ultra USB 3.0 256 GB Pen Drive" products
#
# * The "AmazonBasics Microfiber Bed Sheet Set" products
#
# * The "boAt Airdopes 121 PRO True Wireless in Ear Earbuds" products
#
# * The "TP-LINK WiFi Dongle 300 Mbps Mini Wireless Network USB Wi-Fi Adapter" products
#
# * The "Amazon Pay eGift Card" products
#
# * The "Amazon Basics USB A to Lightning MFi Certified Charging Cable" products
#
# * The "boAt Airdopes 141 Pro True Wireless in Ear Earbuds" products
#
# * The "AmazonBasics 9 Volt Everyday Alkaline Batteries (4-Pack)" product

# %%
# What are the least selling products? 
df_dropped_5.sort_values(['No. Of Ratings', 'Total sales'], ascending=True).head(50)
# Out:
#                                                      Name  \
# 63658   SOOTRA BRANDED carbon film resistor 1/4 watt 4...
# 74866   SOOTRA BRANDED carbon film resistor 1/4 watt 4...
# 194478  ballatha 550 GSM, Grow Bags for Terrace Garden...
# 66400   SOOTRA BRANDED Carbon Film Resistor 1/4 watt 4...
# 79000   SOOTRA BRANDED Carbon Film Resistor 1/4 watt 4...
# ...                                                   ...
# 25971   Spanco Ankle Support Brace Cap Wrap Pad for Me...
# 172150  Shivay Inflating Needle PIN Nozzle Basketball/...
# 31132   ANAVI DIPANYA SHOPPE Baby Boy's & Baby Girl's ...
# 46658   RFS Travel Shoe Bags, Portable Travel Shoe Tot...
# 83655   470nF Polypropylene Capacitor PP 275V EMI supp...
#
#               Main Category                    Sub-category  Ratings  \
# 63658   tv, audio & cameras              Camera Accessories      4.0
# 74866   tv, audio & cameras                         Cameras      4.0
# 194478       home & kitchen               Garden & Outdoors      4.0
# 66400   tv, audio & cameras              Camera Accessories      5.0
# 79000   tv, audio & cameras                         Cameras      5.0
# ...                     ...                             ...      ...
# 25971      sports & fitness  All Sports, Fitness & Outdoors      1.0
# 172150     sports & fitness                        Football      5.0
# 31132         kids' fashion                    Baby Fashion      1.0
# 46658           accessories                  Bags & Luggage      5.0
# 83655       car & motorbike                 Car Electronics      1.0
#
#         No. Of Ratings  Discount Price  Actual Price  Total sales  \
# 63658                1           19.00          39.0        19.00
# 74866                1           19.00          39.0        19.00
# 194478               1           25.00          30.0        25.00
# 66400                1           28.00          88.0        28.00
# 79000                1           28.00          88.0        28.00
# ...                ...             ...           ...          ...
# 25971                1           66.41         149.0        66.41
# 172150               1           67.00         300.0        67.00
# 31132                1           69.00         189.0        69.00
# 46658                1           69.00         149.0        69.00
# 83655                1           69.00          99.0        69.00
#
#         Percentage Discount
# 63658             51.282051
# 74866             51.282051
# 194478            16.666667
# 66400             68.181818
# 79000             68.181818
# ...                     ...
# 25971             55.429530
# 172150            77.666667
# 31132             63.492063
# 46658             53.691275
# 83655             30.303030
#
# [50 rows x 9 columns]

# %%
# List the least selling products? 
df_dropped_5.sort_values(['No. Of Ratings', 'Total sales'], ascending=True).head(50).Name.unique()
# Out:
# array(['SOOTRA BRANDED carbon film resistor 1/4 watt 4 Band Tolerance 5% - Pack of 20pcs (10K Ohms)',
#        'ballatha 550 GSM, Grow Bags for Terrace Gardening 24x24x40 cm - Grow Vegetables Big Size, Fruits, Onion & Other Leafy Vege...',
#        'SOOTRA BRANDED Carbon Film Resistor 1/4 watt 4 Band Tolerance 5% - Total 100pcs Value (1K Ohms)',
#        'SOOTRA 5V Passive Buzzer Acoustic Component Mini Alarm Speaker for electronic project pack of (2)',
#        'SOOTRA 5V Passive Buzzer Acoustic Component Mini Alarm Speaker for electronic project pack of (5)',
#        'SOOTRA 5V Passive Buzzer Acoustic Component Mini Alarm Speaker for electronic project pack of (10)',
#        'Hunky Dory PET Jar 100ml Unbreakable Plastic Transparent with Black Cap Cosmetics Shan Container for Creams,Lip Balm, Body...',
#        '10K ohm 1/4 Watt Resistor 1% Tolerance - 10 Pieces Pack',
#        'Okos Gold Plated Blue and Green Meenakari Radha Krishna Rakshabandhan Alloy Rakhi Bracelet With Multicolour Crystal Stones...',
#        'Loose Orginal Shinning Surma - (1 Pic) (Shinningwala Surma)',
#        'SBWC Stylish Slim Lice Narrow Comb Fine Tooth Dust Lice Clean Remove Plastic Lice Hair Combs Perfect For Lice Nits Eggs Bu...',
#        'Moti Chain Gold Plated Beautiful American Diamond Heart Shape Necklace Golden Chain Pendant for Women and Girls',
#        'Lilone Metal Eiffel Tower Keychain- Bronze | Return Gifts (Size 5cm)',
#        'ZYME® 25 PCS 10K Ohm Resistor 1/2w (0.5 Watt) ±5% Tolerance Metal Film Fixed Resistor',
#        '47nF/630V (0.047uF – 473J) – Polyester Film Capacitor - Pack of 2',
#        '6 Pin C Type USB Connector for Power/Charging Reversible Connector',
#        'Kavi The Poetry-Art Project Kavi Cork Copper Wire led String Lights for Any Bottle, 2M/7.2FT Battery Powered, Ideal for Ga...',
#        '3386P- 2K Ohm 0.5W-Through Hole Trimmer Potentiometer - Pack of 2',
#        'MENTER Arm Sleeves Men & Women Sunlight Protection Protection from Dust, Pollution, Sunburn, UV Protection - Suitable for,...',
#        'Chetran’s Herbal Tofu 200G | Masala Flavor | Fresh Paneer Alternative | High Protein',
#        'Shelfkey.com ALUMINIUM ELECTROLYTIC CAPACITOR 1uF 63V SK-1uF/63V (B-356G) (Pack of 20)',
#        '4.7K ohm Variable Resistor-Preset - 2 pieces pack',
#        '22uF/25V Electrolytic Capacitor - Pack Of 3',
#        'Shelfkey.com NTC THERMISTOR RESISTOR 10OHM 10D 9MM RADIAL (NTC10D9) (B355) SK-NTC-10D-9 (Pack of 20)',
#        'Wired Durable, Stereo Ear Phone for Cell Phones, Laptop, Tablet In Ear Earphones Universal (Multi Colors May Vary)',
#        'Eco-Culture Natural Coconut Dish/Bathroom Scrubber/Scrub Sponge (Pack of 3)',
#        'Shelfkey ALUMINIUM ELECTROLYTIC CAPACITOR 470uF 50V (B337) SK-470uF/50V (PACK OF 4)',
#        'SAARA Kadukkai| Terminalia Chebula| Haritaki ,100g',
#        'Diwali Gift - Om Jewells Rhodium Plated Aqua Blue Solitaire Crystal Hoop Earrings For Girls And Women ER1000056',
#        'Champion Type C PVC Data Cable For Realme X7 Pro,Realme XT USB Cable Original Like Type-C Cable | Type C Rapid Quick Dash ...',
#        'Canvas EP8 Wired Durable, Stereo In Ear Earphone for Cell Phones with HD Mic,for Laptop, Tablet Ear Phones Universal (Mult...',
#        'Bigwig MATTE BLUE EYELINER',
#        'MeeTo Automatic Telescopic Body Measuring Tape with Lock Pin and Push Button 60 inch (150cm)',
#        'MeeTo Makeup Foundation Blend Blush Brush With Sponge Puff Combo Pack of 2',
#        'PREPLE Neem Coated Urea Fertilizer for Gardening Purpose Nutrient 46% Nitrogen Water Soluble Best For Garden Plants Growth...',
#        'Sports Wallet for Men (Black Sports)',
#        'SHELFKEY WIREWOUND RESISTOR 1 OHM 10WATT AXIAL SK-1OHM-10WATT (PACK OF 2)',
#        'UNIVERSAL HUB® Combo of 20 Multicolour led (Red,Blue,White,Green,Yellow) 4 Pieces Each Color Input 3v-3.2v High Brightness...',
#        'TIMELINE Wash Basin and Sink Cleaning Multipurpose Brush (Multicolor) (1)',
#        'Spanco Ankle Support Brace Cap Wrap Pad for Men and Women | Ankle Support for Pain Relief | Ankle Support for Sports | Ank...',
#        'Shivay Inflating Needle PIN Nozzle Basketball/Football Ball AIR Pump',
#        "ANAVI DIPANYA SHOPPE Baby Boy's & Baby Girl's Soft Woolen Winter Warm Kids Hand Gloves (Multicolor; Pack of 1 pair) (1-2 Y...",
#        'RFS Travel Shoe Bags, Portable Travel Shoe Tote Bags - Packing Organizers for Men Women and Children (Multicolore) 1 pcs',
#        '470nF Polypropylene Capacitor PP 275V EMI suppression capacitors (MPX)'],
#       dtype=object)

# %% [markdown]
# ### The 10 least selling products are:
#
# * 'SOOTRA BRANDED carbon film resistor 1/4 watt 4 Band Tolerance 5% - Pack of 20pcs (10K Ohms)'
#
# * '10K ohm 1/4 Watt Resistor 1% Tolerance - 10 Pieces Pack'
#
# *  'Okos Gold Plated Blue and Green Meenakari Radha Krishna Rakshabandhan Alloy Rakhi Bracelet With Multicolour Crystal Stones...'
#
# *  'SBWC Stylish Slim Lice Narrow Comb Fine Tooth Dust Lice Clean Remove Plastic Lice Hair Combs Perfect For Lice Nits Eggs Bu...'
#
# * 'Moti Chain Gold Plated Beautiful American Diamond Heart Shape Necklace Golden Chain Pendant for Women and Girls'
#
# * 'Kavi The Poetry-Art Project Kavi Cork Copper Wire led String Lights for Any Bottle, 2M/7.2FT Battery Powered, Ideal for Ga...'
#
# * '3386P- 2K Ohm 0.5W-Through Hole Trimmer Potentiometer - Pack of 2'
#
# * 'MENTER Arm Sleeves Men & Women Sunlight Protection Protection from Dust, Pollution, Sunburn, UV Protection - Suitable for,...'
#
# * 'Chetran’s Herbal Tofu 200G | Masala Flavor | Fresh Paneer Alternative | High Protein'
#
# * 'Shelfkey.com ALUMINIUM ELECTROLYTIC CAPACITOR 1uF 63V SK-1uF/63V (B-356G)

# %% [markdown]
# ## Phase 6: Data visualization

# %%
# Let's first visualize the sales per individual product categories for all categories
plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")
sns.barplot(data=sales_per_cat, y = 'Main Category', x = 'No. Of Ratings')
plt.show()

# %%
# Let's first visualize the most popular product categories individually
plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")
sns.barplot(data=popular_product_cat, y = 'Main Category', x = 'No. Of Ratings')
plt.show()

# %%
# Let's first visualize the most popular product categories as a whole
plt.pie(x=popular_product_cat['No. Of Ratings'], labels=popular_product_cat['Main Category'], radius=2.5, \
                autopct = '%.2f%%', labeldistance=1.02)
plt.show()

# %%
# Let's first visualize the most popular product sub-categories individually
plt.figure(figsize=(20, 10))
sns.set_style("whitegrid")
sns.barplot(data=popular_product_sub_cat, y = 'Sub-category', x = 'No. Of Ratings')
plt.show()

# %%
# Let's first visualize the most popular product sub-categories as a whole
plt.pie(x=popular_product_sub_cat['No. Of Ratings'], labels=popular_product_sub_cat['Sub-category'], radius=2.5, \
                autopct = '%.2f%%', labeldistance=1.02)
plt.show()

# %%
# What are the most popular products by ratings?
# first we drop duplicates and pass to a new variable
pop_prod_by_rat_h = pop_prod_by_rat[['Name', 'Ratings', 'No. Of Ratings']].drop_duplicates()
pop_prod_by_rat_h
# Out:
#                                                      Name  Ratings  \
# 66723   SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...      4.3
# 68452   SanDisk 512GB Ultra MicroSDXC UHS-I Memory Car...      4.3
# 62204   SanDisk Extreme Pro SD UHS I 1TB Card for 4K V...      4.5
# 19215   Redmi Note 10S (Cosmic Purple, 6GB RAM, 128GB ...      4.2
# 13904   Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB S...      4.2
# 15424   Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage)...      4.1
# 256576  Redmi 164 cm (65 inches) 4K Ultra HD Android S...      4.2
#
#         No. Of Ratings
# 66723           589547
# 68452           589547
# 62204           215311
# 19215           221269
# 13904           221269
# 15424           319396
# 256576           47642

# %%
# we need to pivot the dataframe first if we use heatmap
dfp = pop_prod_by_rat_h.pivot('Name', 'Ratings', 'No. Of Ratings')
dfp
# Out:
# Ratings                                                  4.1       4.2  \
# Name
# Redmi 164 cm (65 inches) 4K Ultra HD Android Sm...       NaN   47642.0
# Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) ...  319396.0       NaN
# Redmi Note 10S (Cosmic Purple, 6GB RAM, 128GB S...       NaN  221269.0
# Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB St...       NaN  221269.0
# SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-40...       NaN       NaN
# SanDisk 512GB Ultra MicroSDXC UHS-I Memory Card...       NaN       NaN
# SanDisk Extreme Pro SD UHS I 1TB Card for 4K Vi...       NaN       NaN
#
# Ratings                                                  4.3       4.5
# Name
# Redmi 164 cm (65 inches) 4K Ultra HD Android Sm...       NaN       NaN
# Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) ...       NaN       NaN
# Redmi Note 10S (Cosmic Purple, 6GB RAM, 128GB S...       NaN       NaN
# Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB St...       NaN       NaN
# SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-40...  589547.0       NaN
# SanDisk 512GB Ultra MicroSDXC UHS-I Memory Card...  589547.0       NaN
# SanDisk Extreme Pro SD UHS I 1TB Card for 4K Vi...       NaN  215311.0

# %%
# We then plot the heatmap of the pivoted dfp
plt.figure(figsize=(12, 10))
plt.title('the most popular products by ratings')
sns.set_style("darkgrid")
sns.heatmap(dfp, annot=True)
plt.show()

# %%
# Let's look at the total sales and number of sales data per rating..
pd.set_option("display.max.rows", None) # make sure pandas does not hide any rows
total_sales_ratings
# Out:
#     Ratings  No. Of Ratings   Total sales
# 40      5.0           56355  1.200519e+08
# 39      4.9           66228  5.629130e+08
# 38      4.8         1054777  5.864115e+09
# 37      4.7         2592571  2.348309e+10
# 36      4.6         6669347  3.268816e+10
# 35      4.5        21375391  7.546737e+10
# 34      4.4        35717810  7.816579e+10
# 33      4.3        39475459  1.259095e+11
# 32      4.2        39558757  1.319741e+11
# 31      4.1        49442397  9.682539e+10
# 30      4.0        23112603  3.944909e+10
# 29      3.9        22768853  3.339670e+10
# 28      3.8        17249033  2.355845e+10
# 27      3.7         9551995  1.073098e+10
# 26      3.6         6297226  5.557731e+09
# 25      3.5         5246494  5.090270e+09
# 24      3.4         2395808  3.166459e+09
# 23      3.3         1363887  1.080078e+09
# 22      3.2          990849  1.994229e+09
# 21      3.1          450916  5.490178e+08
# 20      3.0          211519  1.948724e+08
# 19      2.9          149081  1.105535e+08
# 18      2.8           73919  6.582079e+07
# 17      2.7           45624  4.282118e+07
# 16      2.6           28039  3.520783e+07
# 15      2.5           17485  1.737756e+07
# 14      2.4           10493  1.151943e+07
# 13      2.3            8582  1.109023e+07
# 12      2.2            5155  4.805342e+06
# 11      2.1            3493  4.977939e+06
# 10      2.0            6324  7.794467e+06
# 9       1.9            1729  2.195811e+06
# 8       1.8            1542  1.733414e+06
# 7       1.7            1037  1.267670e+06
# 6       1.6             833  8.280068e+05
# 5       1.5            1307  1.376513e+06
# 4       1.4             616  5.008256e+05
# 3       1.3             363  3.026018e+05
# 2       1.2             164  3.734000e+05
# 1       1.1              10  6.990000e+03
# 0       1.0            8957  1.482493e+07

# %%
# Let's visualize the total sales of products per rating
plt.figure(figsize=(18, 8))
sns.barplot(data=total_sales_ratings, x ='Ratings', y= 'Total sales')
plt.show()

# %%
# Let's visualize the number of sales of products per rating
plt.figure(figsize=(18, 8))
sns.barplot(data=total_sales_ratings, x ='Ratings', y= 'No. Of Ratings')
plt.show()

# %%
# Once more lets examine the data for popular products per each rating..
pop_prod_rating
# Out:
#         Ratings                                               Name  \
# 502813      5.0  FIGMENT Dancing Cactus Talking Toy, Cactus Plu...
# 127564      4.9  Pampers Swaddlers Disposable Baby Diapers, New...
# 244416      4.8  Bounty Personal Air Cooler with Anti Bacterial...
# 96242       4.7                    Hey Dude Men's Wally Sox Loafer
# 507020      4.6                              Amazon Pay eGift Card
# 18802       4.5  AmazonBasics AA Performance Alkaline Non-Recha...
# 60378       4.4  Amazon Basics High-Speed HDMI Cable - 10 Feet ...
# 60737       4.3  SanDisk 128GB Class 10 microSDXC Memory Card w...
# 13904       4.2  Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB S...
# 11583       4.1  boAt BassHeads 100 in-Ear Wired Headphones wit...
# 12127       4.0  boAt Airdopes 441 Bluetooth Truly Wireless in ...
# 265318      3.9  AmazonBasics Microfiber Sheet Set - (Includes ...
# 11588       3.8  boAt Airdopes 121v2 in-Ear True Wireless Earbu...
# 11970       3.7  JBL Tune 215BT, 16 Hrs Playtime with Quick Cha...
# 416053      3.6  Nano Double Sided Tape, EZlifego Traceless Was...
# 11608       3.5  pTron Bassbuds Duo in Ear Earbuds with 32Hrs T...
# 15351       3.4  Skullcandy Dime True Wireless in-Ear Bluetooth...
# 11673       3.3  Tygot Adjustable Aluminium Alloy Tripod Stand ...
# 234789      3.2  Skullcandy Indy Evo Truly Wireless Bluetooth i...
# 266530      3.1  TECHVIDA GLANDOTU Automatic Wireless Portable ...
# 85419       3.0                               Big Fox Men's Loafer
# 28182       2.9                          T-Rock Men's Sports Shoes
# 374694      2.8  NEOSAFE Spark A5005 PVC Labour Safety Shoes (8...
# 24226       2.7  Kuber Industries Wooden Simple Numerical Round...
# 1808        2.6  Prestige Roti Maker PRM 5.0 with Demo CD - Silver
# 13743       2.5  DEVCOMM Phone Bluetooth Stereo System Audio Au...
# 80617       2.4  Car Vacuum Powerful Portable & High Power 12V ...
# 87217       2.3       Bond Street by (Red Tape) Men Brown Moccasin
# 266262      2.2  Shreeji Water Manual Pump Dispenser for 20 Lit...
# 438150      2.1  Sasta Kashmiri walnut without shell in vacuum ...
# 383409      2.0                 Puma Unisex Bosco Jr 2 Dp Sneakers
# 92034       1.9  Bond Street by (Red Tape) Men's Tan Loafers-8 ...
# 438069      1.8  Dried Treats Premium Almonds (Kagzi Almonds, 2...
# 5532        1.7  FnX® Mini Iron Portable Travel Iron Support Dr...
# 1376        1.6  Suzec Mini Heat Sealing Machine for Home Use, ...
# 85665       1.5                         Puma Men's Polo Boat Shoes
# 11361       1.4  Mr Fix® 3D Car Door Invisible Handle Cup Scrat...
# 236106      1.3  GoSale Bluetooth Neckband for OnePlus Earphone...
# 379866      1.2  Kuber Industries Rubber Bathroom Slipper For M...
# 268520      1.1  Citroda Electric Mosquito Killer Lamp USB Rech...
# 234570      1.0  Celly BUZ1 True Wireless Headset, Bluetooth 5....
#
#         No. Of Ratings   Total sales
# 502813              99  6.920100e+04
# 127564           26160  3.402893e+08
# 244416           80282  3.210477e+08
# 96242            84311  8.351848e+08
# 507020          182473  1.824730e+06
# 18802           336487  3.125964e+08
# 60378           437652  1.658701e+08
# 60737           589547  1.005178e+09
# 13904           221269  3.318814e+09
# 11583           375110  1.496689e+08
# 12127           148271  1.926040e+08
# 265318          190982  1.965205e+08
# 11588           188031  2.066461e+08
# 11970            84439  1.265741e+08
# 416053           81051  1.945224e+07
# 11608           166395  1.329496e+08
# 15351            41533  1.037910e+08
# 11673            53252  1.751991e+07
# 234789           35122  2.206364e+08
# 266530           37772  1.469331e+07
# 85419             2926  1.752674e+06
# 28182             9601  2.861098e+06
# 374694            6942  2.672670e+06
# 24226             1977  6.879960e+05
# 1808              1411  4.055214e+06
# 13743             1225  1.715000e+05
# 80617              282  3.381180e+05
# 87217              183  1.180350e+05
# 266262             128  3.059200e+04
# 438150             208  7.904000e+04
# 383409             150  1.014000e+05
# 92034               56  4.284000e+04
# 438069              80  7.053600e+03
# 5532                43  2.790700e+04
# 1376                58  8.642000e+03
# 85665               73  5.591800e+04
# 11361                9  1.611000e+03
# 236106              11  5.489000e+03
# 379866              23  1.413580e+03
# 268520              10  6.990000e+03
# 234570               9  2.001600e+04

# %%
# To see the visual correlation between 'Ratings' and 'No. Of Ratings' in the popular products per rating
plt.figure(figsize=(12, 7))
sns.regplot(data=pop_prod_rating, x='Ratings', y='No. Of Ratings')
plt.show()

# %%
# Checking for the correlation coefficient between the numerical fields in the popular products data (per rating)
pop_prod_rating.corr(method='pearson')[['Total sales']]
# Out:
#                      Total sales
# Ratings                 0.029481
# No. Of Ratings          0.476932
# Discount Price          0.113520
# Actual Price           -0.000030
# Total sales             1.000000
# Percentage Discount    -0.034406

# %%
# Considering the popular products BY ratings data..
pd.set_option("display.max.rows", 10) # reduce the number of records shown to default
pop_prod_by_rating = df_dropped_5.sort_values(['Total sales', 'No. Of Ratings','Ratings'], ascending = False)
pop_prod_by_rating
# Out:
#                                                      Name  \
# 66723   SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...
# 79485   SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...
# 68452   SanDisk 512GB Ultra MicroSDXC UHS-I Memory Car...
# 62204   SanDisk Extreme Pro SD UHS I 1TB Card for 4K V...
# 72681   SanDisk Extreme Pro SD UHS I 1TB Card for 4K V...
# ...                                                   ...
# 440273  SOOTRA 5V Passive Buzzer Acoustic Component Mi...
# 441322  SOOTRA 5V Passive Buzzer Acoustic Component Mi...
# 194478  ballatha 550 GSM, Grow Bags for Terrace Garden...
# 63658   SOOTRA BRANDED carbon film resistor 1/4 watt 4...
# 74866   SOOTRA BRANDED carbon film resistor 1/4 watt 4...
#
#               Main Category        Sub-category  Ratings  No. Of Ratings  \
# 66723   tv, audio & cameras  Camera Accessories      4.3          589547
# 79485   tv, audio & cameras             Cameras      4.3          589547
# 68452   tv, audio & cameras  Camera Accessories      4.3          589547
# 62204   tv, audio & cameras  Camera Accessories      4.5          215311
# 72681   tv, audio & cameras             Cameras      4.5          215311
# ...                     ...                 ...      ...             ...
# 440273  tv, audio & cameras            Speakers      5.0               1
# 441322  tv, audio & cameras            Speakers      5.0               1
# 194478       home & kitchen   Garden & Outdoors      4.0               1
# 63658   tv, audio & cameras  Camera Accessories      4.0               1
# 74866   tv, audio & cameras             Cameras      4.0               1
#
#         Discount Price  Actual Price   Total sales  Percentage Discount
# 66723          15600.0       22289.0  9.196933e+09            30.010319
# 79485          15600.0       22289.0  9.196933e+09            30.010319
# 68452           8022.0       15000.0  4.729346e+09            46.520000
# 62204          17999.0       51000.0  3.875383e+09            64.707843
# 72681          17999.0       51000.0  3.875383e+09            64.707843
# ...                ...           ...           ...                  ...
# 440273            28.0         144.0  2.800000e+01            80.555556
# 441322            28.0         144.0  2.800000e+01            80.555556
# 194478            25.0          30.0  2.500000e+01            16.666667
# 63658             19.0          39.0  1.900000e+01            51.282051
# 74866             19.0          39.0  1.900000e+01            51.282051
#
# [334963 rows x 9 columns]

# %%
# Checking for the correlation coefficient between the numerical fields in the popular products data (by rating)
pop_prod_by_rating.head(500).corr(method='pearson')[['Total sales']]
# Out:
#                      Total sales
# Ratings                -0.004843
# No. Of Ratings          0.380679
# Discount Price          0.059969
# Actual Price            0.056788
# Total sales             1.000000
# Percentage Discount    -0.065618

# %%
# Checking for the correlation coefficient between the numerical fields in the whole cleaned dataset!
df_dropped_5.corr(method='pearson')[['Total sales']]
# Out:
#                      Total sales
# Ratings                 0.029481
# No. Of Ratings          0.476932
# Discount Price          0.113520
# Actual Price           -0.000030
# Total sales             1.000000
# Percentage Discount    -0.034406

# %% [markdown]
# ### A finding from the two correlations above shows that there is
# * A positive moderate correlation between 'Total sales' and 'No. Of Ratings'. Value = 0.476932
# * A slightly negative correlation between 'Total sales' and 'Percentage discount'. Value = -0.034406

# %% [markdown]
# ## Phase 7: Reporting the findings
#
# ### The dataset:
#
# * The **Amazon Product Sales** dataset has quite a large number of records which makes it good for analytics. The required fields were present such as Actual Price, No. Of Ratings, etc.
# * The **Amazon Product Sales** dataset has a lot of missing values as well as invalid entries in some fields as seen during the Data Cleaning phase of this analytics project. This required great skill and time in cleaning.
#
#
# ### Summary of the Insights from the data analysis:
#
# ##### The popular product categories that seemed to generate most sales and ratings were observed to be:
#
# 1) TV, audio & cameras
#
# 2) Stores
#
# 3) Appliances
#
# 4) Women's clothing
#
# 5) Toys & baby products
#
# 6) Accessories
#
# 7) Beauty & health
#
# 8) Home & kitchen
#
#
# ##### The popular product Sub-categories that seemed to generate most sales and ratings were observed to be:
#
# 1) All Electronics
#
# 2) Headphones
#
# 3) Cameras
#
# 4) Camera Accessories
#
# 5) Home Entertainment Systems
#
# 6) Men's Fashion
#
# 7) All Appliances
#
# 8) Kitchen & Home Appliances
#
# 9) Amazon Fashion
#
# 10) Bags & Luggage
#
#
# ##### Some of the most popular and best selling products were found to be:
#
# 1) SanDisk products especially Memory Cards
#
# 2) Redmi products especially Smartphones
#
# 3) AmazonBasics Alkaline Batteries and HDMI cables
#
# 4) boAt Bassheads and Eardopes products
#
# 5) Huggins Wonderpants Diapers
#
#
# #### Most sales were observed to come from products in the range of 3.1 to 4.9 product ratings.
#
#
# ##### Some of the products that are doing badly in sales are:
#
# 1) SOOTRA BRANDED carbon film resistor
#
# 2) Okos Gold Plated Blue and Green Bracelet
#
# 3) SBWC Stylish Slim Lice Narrow Comb
#
# 4) Moti Chain Gold Plated Necklace Golden Chain Pendant for Women..
#
# 5) Shelfkey.com ALUMINIUM ELECTROLYTIC CAPACITOR
#
# </br>
#
# ### The answers to the Analytics Questions:
#
# ##### It was seen that one important trend in product sales is that the buyers tend to buy products from the SAME brand as a top-selling product.
#
# ##### Buyers also tend to buy from well-rated products in categories, as well as products that have higher number of ratings (as seen in the correlation data)
#
# ##### Important factors affecting product sales are:
#
# 1) Well-established product categories such as Electronics, Appliances, and Clothing seem to attract most sales,
#
# 2) Discount doesn't seem to encourage sales. In fact it was observed that well discounted products have lower sales (as seen in the correlation coefficient data),
#
# 3) Price of item (original price) has no effect on volume of sales.

# %% [markdown]
# #### Thank you!
